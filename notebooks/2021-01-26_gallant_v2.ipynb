# %%
from pathlib import Path
import pprint
import os
import json

# %%
import numpy as np
import pandas as pd
import xarray as xr
import jmespath
from brainio_collection import list_stimulus_sets, list_assemblies, get_stimulus_set, get_assembly
# Out:
# Loading lookup from /braintree/home/jjpr/dev/brainio_collection/brainio_collection/lookup.csv

# %%
import plotly.express as px

# %%
from plotly.subplots import make_subplots

# %%
import plotly.graph_objects as go

# %%
from brainio_base.assemblies import NeuronRecordingAssembly

# %%
import scipy.io as sio

# %%
import re

# %%
source_netcdf_file = "/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/crcns_v2-1_neuronal.nc"

# %%
v2 = NeuronRecordingAssembly(xr.open_dataarray(source_netcdf_file))
v2

# %%
v2_nans = np.count_nonzero(np.isnan(v2))
print(v2.size - v2_nans)
print(v2_nans)
print(v2.size)
v2_nans/v2.size

# %%
example_csv_path = Path("/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data10/NatRev/data/e0052.edrev3.001.p1.mat.csv")

# %%
example_mat_path = Path("/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data10/NatRev/e0052/e0052.edrev3.001.p1.mat")

# %%
example_csv = pd.read_csv(example_csv_path)
example_csv

# %%
example_mat = sio.loadmat(example_mat_path)
example_mat

# %%
example_mat["psth"].shape

# %%
for k, v in example_mat.items():
    if hasattr(v, "shape"):
        print(f"{k}:  {v.dtype} {v.shape}")
    else: 
        print(f"{k}: {type(v)}")

# %%
v2_path = example_csv_path.parents[3]
v2_path
# Out:
# PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1')

# %%
v2_path_glob = pprint.pformat(list(example_csv_path.parents[3].glob("**")))
v2_path_glob

# %%
v2_path_walk = pprint.pformat(list(os.walk(v2_path)))
v2_path_walk

# %%
print(v2_path_glob)

# %%
print(v2_path_walk)

# %%
v2_tree_path = Path("/braintree/home/jjpr/dev/brainio_contrib/mkgu_packaging/gallant/v2/v2_dir_tree.json")

# %%
v2_tree = json.load(v2_tree_path.open())
v2_tree

# %%
type(v2_tree)

# %%
jmespath.search("[*].type", v2_tree)

# %%
jmespath.search("[*].keys(@)", v2_tree)

# %%
jmespath.search("[0].name", v2_tree)

# %%
jmespath.search("[0].contents.length(@)", v2_tree)

# %%
dir()

# %%
example_csv_df = pd.read_csv(example_csv_path)
example_csv_df

# %%
example_mat["r"]

# %%
type(example_mat["r"])

# %%
example_mat["r"].shape

# %%
example_mat["r"][:10,:]

# %%
example_mat["r"][:100,:10]

# %%
example_mat["r"][1000:1100,:10]

# %%
ex_nanmean = np.nanmean(example_mat["r"], 1)
ex_nanmean

# %%
ex_nanmean.shape

# %%
np.isnan(ex_nanmean)

# %%
sum(np.isnan(ex_nanmean))

# %% [raw]
# files = glob([directory, '/V2Data*/', stimuliType, '/*/*summary_file.mat']);
#
# summaries.celldata
#
#         responseFile = [subDir, '/', summary.respfile];
#         response = respload(responseFile);

# %%
[f for f in v2_path.iterdir()]

# %%
summaries_glob = sorted(v2_path.glob("V2Data*/**/*summary_file.mat"))
[f.relative_to(v2_path) for f in summaries_glob]
# Out:
# [PosixPath('V2Data1/DGrat/e0022/e0022.edrev3.007.p1_summary_file.mat'),
#  PosixPath('V2Data1/DGrat/e0026/e0026.edrev3.005.p1_summary_file.mat'),
#  PosixPath('V2Data1/DGrat/e0031/e0031.edrev3.006.p1_summary_file.mat'),
#  PosixPath('V2
edrev3.003.p1_summary_file.mat'),
#  PosixPath('V2Data2/DGrat/e0076/e0076.edrev3.006.p1_summary_file.mat'),
#  PosixPath('V2Data2/DGrat/e0078/e0078.edrev3.006.p1_summary_file.mat'),
#  PosixPath('V2Data2/DGrat/e0080/e0080.edrev3.004.p1_summary_file.mat'),
#  PosixPath('V2Data2/DGrat/e0080/e0080.edrev3.008.p1_summary_file.mat'),
#  PosixPath('V2Data2/DGrat/e0107/e0107.edrev3.013.p1_summary_file.mat'),
#  PosixPath('V2Data2/DGrat/e0108/e0108.edrev3.012.p1_summary_file.mat'),
#  PosixPath('V2Data2/DGrat/e0109/e0109.edrev3.006.p1_summary_file.mat'),
#  PosixPath('V2Data2/DGrat/e0110/e0110.edrev3.007.p1_summary_file.mat'),
#  PosixPath('V2Data20/NatRev/z0127/z0127.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('V2Data20/NatRev/z0127/z0127.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('V2Data20/NatRev/z0128/z0128.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('V2Data20/NatRev/z0128/z0128.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('V2Data20/NatRev/z0129/z0129.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('V2Data20/NatRev/z0129/z0129.ezrev4.003.p1_summary_file.mat'),
#  PosixPath('V2Data20/NatRev/z0131/z0131.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('V2Data20/NatRev/z0131/z0131.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0115/e0115.edrev3.006.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0121/e0121.edrev3.009.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0121/e0121.edrev3.010.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0121/e0121.edrev3.011.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0121/e0121.edrev3.012.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0123/e0123.edrev3.006.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0124/e0124.edrev3.007.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0125/e0125.edrev3.008.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0128/e0128.edrev3.004.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0128/e0128.edrev3.005.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/e0128/e0128.edrev3.006.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/r0313/r0313.rev.003.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/r0314/r0314.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/r0315/r0315.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/r0315/r0315.rev.003.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/r0317/r0317.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data3/DGrat/r0317/r0317.rev.005.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0318/r0318.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0327/r0327.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0327/r0327.rev.002.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0328/r0328.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0329/r0329.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0330/r0330.rev.003.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0332/r0332.rev.002.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0333/r0333.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0336/r0336.rev.002.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0336/r0336.rev.005.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0336/r0336.rev.006.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0337/r0337.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0337/r0337.rev.004.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0337/r0337.rev.005.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0340/r0340.rev.004.p1_summary_file.mat'),
#  PosixPath('V2Data4/DGrat/r0340/r0340.rev.005.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0342/r0342.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0342/r0342.rev.002.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0343/r0343.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0343/r0343.rev.002.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0344/r0344.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0345/r0345.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0347/r0347.rev.002.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0347/r0347.rev.007.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0347/r0347.rev.010.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0348/r0348.rev.004.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0348/r0348.rev.008.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0350/r0350.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0352/r0352.rev.000.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0353/r0353.rev.002.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0357/r0357.rev.003.p1_summary_file.mat'),
#  PosixPath('V2Data5/DGrat/r0357/r0357.rev.011.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/r0358/r0358.rev.001.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/r0358/r0358.rev.002.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/r0360/r0360.rev.006.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/z0111/z0111.edrev3.012.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/z0112/z0112.edrev3.004.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/z0114/z0114.ezrev4.004.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/z0117/z0117.ezrev4.004.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/z0119/z0119.ezrev4.004.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/z0120/z0120.ezrev4.004.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/z0124/z0124.ezrev4.003.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/z0126/z0126.ezrev4.004.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/z0127/z0127.ezrev4.004.p1_summary_file.mat'),
#  PosixPath('V2Data6/DGrat/z0131/z0131.ezrev4.004.p1_summary_file.mat'),
#  PosixPath('V2Data7/Nat/e0022/e0022.edrev3.006.p1_summary_file.mat'),
#  PosixPath('V2Data7/Nat/e0031/e0031.edrev3.009.p1_summary_file.mat'),
#  PosixPath('V2Data7/Nat/e0076/e0076.edrev3.009.p1_summary_file.mat'),
#  PosixPath('V2Data7/Nat/e0078/e0078.edrev3.007.p1_summary_file.mat'),
#  PosixPath('V2Data7/Nat/e0080/e0080.edrev3.007.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0017/e0017.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0017/e0017.edrev3.003.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0018/e0018.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0018/e0018.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0021/e0021.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0021/e0021.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0022/e0022.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0022/e0022.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0022/e0022.edrev3.009.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0022/e0022.edrev3.010.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0024/e0024.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data7/NatRev/e0024/e0024.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0026/e0026.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0026/e0026.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0026/e0026.edrev3.008.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0028/e0028.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0028/e0028.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0029/e0029.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0030/e0030.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0031/e0031.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0031/e0031.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0031/e0031.edrev3.008.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0032/e0032.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0032/e0032.edrev3.003.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0033/e0033.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0033/e0033.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0033/e0033.edrev3.008.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0034/e0034.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0034/e0034.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0035/e0035.edrev3.003.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0035/e0035.edrev3.004.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0036/e0036.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data8/NatRev/e0036/e0036.edrev3.003.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0037/e0037.edrev3.003.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0037/e0037.edrev3.004.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0039/e0039.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0039/e0039.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0040/e0040.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0040/e0040.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0043/e0043.edrev3.003.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0043/e0043.edrev3.004.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0043/e0043.edrev3.009.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0046/e0046.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0046/e0046.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0047/e0047.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0047/e0047.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0047/e0047.edrev3.006.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0047/e0047.edrev3.007.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0048/e0048.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0048/e0048.edrev3.003.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0049/e0049.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0050/e0050.edrev3.002.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0050/e0050.edrev3.003.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0050/e0050.edrev3.010.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0051/e0051.edrev3.001.p1_summary_file.mat'),
#  PosixPath('V2Data9/NatRev/e0051/e0051.edrev3.002.p1_summary_file.mat')]

# %%
len(summaries_glob)
# Out:
# 417

# %%
summaries_glob[0]

# %%
# re.split('(\d+)', s.relative_to(v2_path).parts[0])
# (lambda s: s.relative_to(v2_path).parts[0] )(summaries_glob[0])
# (lambda s: re.split('(\d+)', s.relative_to(v2_path).parts[0]) )(summaries_glob[0])
(lambda s: int(re.findall('(\d+)', s.relative_to(v2_path).parts[0])[-1]) )(summaries_glob[0])

# [f.relative_to(v2_path) for f in summaries_glob]

# %%
dir_key = lambda s: int(re.findall('(\d+)', s.relative_to(v2_path).parts[0])[-1])
summaries_glob = sorted(summaries_glob, key=dir_key)
summaries_glob
# Out:
# [PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2
003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data17/NatRev/r0336/r0336.rev.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data17/NatRev/r0337/r0337.rev.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data17/NatRev/r0337/r0337.rev.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data17/NatRev/r0340/r0340.rev.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data17/NatRev/r0340/r0340.rev.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data17/NatRev/r0343/r0343.rev.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data17/NatRev/r0343/r0343.rev.004.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data17/NatRev/r0344/r0344.rev.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data17/NatRev/r0344/r0344.rev.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data17/NatRev/r0344/r0344.rev.004.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0345/r0345.rev.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0345/r0345.rev.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0347/r0347.rev.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0347/r0347.rev.004.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0347/r0347.rev.005.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0347/r0347.rev.008.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0347/r0347.rev.009.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0348/r0348.rev.005.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0348/r0348.rev.006.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0348/r0348.rev.007.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0349/r0349.rev.000.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0352/r0352.rev.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0352/r0352.rev.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0353/r0353.rev.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0353/r0353.rev.004.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0357/r0357.rev.004.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0357/r0357.rev.005.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0357/r0357.rev.006.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0357/r0357.rev.007.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0357/r0357.rev.008.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0357/r0357.rev.015.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0357/r0357.rev.016.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0357/r0357.rev.017.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0357/r0357.rev.018.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0358/r0358.rev.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0358/r0358.rev.004.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/r0358/r0358.rev.005.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/z0109/z0109.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/z0109/z0109.ezrev4.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/z0109/z0109.ezrev4.005.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/z0111/z0111.edrev3.009.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data18/NatRev/z0111/z0111.ezrev4.008.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0112/z0112.edrev3.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0112/z0112.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0114/z0114.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0114/z0114.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0115/z0115.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0115/z0115.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0117/z0117.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0117/z0117.ezrev4.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0118/z0118.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0119/z0119.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0119/z0119.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0120/z0120.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0120/z0120.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0124/z0124.ezrev4.000.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0124/z0124.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0125/z0125.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0125/z0125.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0126/z0126.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data19/NatRev/z0126/z0126.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data20/NatRev/z0127/z0127.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data20/NatRev/z0127/z0127.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data20/NatRev/z0128/z0128.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data20/NatRev/z0128/z0128.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data20/NatRev/z0129/z0129.ezrev4.002.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data20/NatRev/z0129/z0129.ezrev4.003.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data20/NatRev/z0131/z0131.ezrev4.001.p1_summary_file.mat'),
#  PosixPath('/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data20/NatRev/z0131/z0131.ezrev4.002.p1_summary_file.mat')]

# %%
s = summaries_glob[-1]
mat = sio.loadmat(s)
for k, v in mat.items():
    if hasattr(v, "shape"):
        print(f"{k}:  {v.dtype} {v.shape}")
    else: 
        print(f"{k}: {type(v)}")

# %%
mat["celldata"].dtype

# %%
s

# %%
type(mat["celldata"])

# %%
mat["celldata"].shape

# %%
mat["celldata"][0].shape

# %%
mat["celldata"][0]

# %%
mat["celldata"].dtype.fields

# %%
[f"{name}:  {mat['celldata'][name]}" for name in mat["celldata"].dtype.names]

# %%
summ_top_fields = {}
for s in summaries_glob:
    rel_path = s.relative_to(v2_path)
    mat = sio.loadmat(s)
    fields = {}
    for k, v in mat.items():
        if hasattr(v, "shape"):
            fields[k] = (v.dtype, v.shape)
        else: 
            fields[k] = type(v)
    summ_top_fields[rel_path] = fields
    print(rel_path, fields.keys())

# %%
for k, v in summ_top_fields.items():
    print(k, v["celldata"][1])

# %%
for k, v in summ_top_fields.items():
    print(k, v["celldata"][0].names)

# %%
for k, v in summ_top_fields.items():
    print(v["celldata"][0].names[:12])

# %%
for k, v in summ_top_fields.items():
    print(v["celldata"][0].names[12:22])

# %%
for k, v in summ_top_fields.items():
    print(v["celldata"][0].names[22:])

# %%
list(summ_top_fields.values())[-1]["celldata"][0].names

# %%
('id',
 'cellid',
 'masterid',
 'rawid',
 'celldataid',
 'runclassid',
 'path',
 'resplen',
 'repcount',
 'respfile',
 'respvarname',
 'respfiletype',
 'nosync',
 'respfilefmt',
 'respfmtcode',
 'stimfile',
 'stimfiletype',
 'stimiconside',
 'stimfilecrf',
 'stimwindowsize',
 'stimfilefmt',
 'stimfmtcode',
 'addedby',
 'info',
 'lastmod',
 'stimpath',
 'stimspeedid',
 'spikes',
 'a_state',
 'singleid',
 'singlerawid',
 'area',
 'bad',
 'rawstimfile',
 'well')

# %%
sample_fields = [
  'cellid',
  'resplen',
  'repcount',
  'respfile',
  'respfilefmt',
  'respvarname',
  'respfiletype',
  'spikes',
  'area'
]

# %%
celldatas = {}
for s in summaries_glob:
    rel_path = s.relative_to(v2_path)
    mat = sio.loadmat(s, squeeze_me=True)
    celldatas[rel_path] = mat["celldata"]
celldatas
# Out:
# {PosixPath('V2Data1/DGrat/e0022/e0022.edrev3.007.p1_summary_file.mat'): array((8846, 'e0022', 788, 2901, 0, 1, '/auto/data/archive/ed_data/e2004-03-18/', 7915, 1, 'e0022.edrev3.007.p1.mat', 'psth', 0, 0, 'PSTH', 0, 'gratrev2004-160.index60.1.pixel.imsm', 1, '160,160', 3.2, 160, 'pixel', 0, 'willmore', 'checkraw2cell.m', '2005-01-08 15:56:43', '/auto/data/archive/stimarchive/ED02/imsm/', 60, 5852, array([], dtype=float64), 773, 3796, 'V2', 0, 'index60.1', 1),
#        dtype=[('id', 'O'), ('cellid', 'O'), ('masterid', 'O'), ('rawid', 'O'), ('celldataid', 'O'), ('runclassid', 'O'), ('path', 'O'), ('resplen', 'O'), ('repcount', 'O'), ('respfile', 'O'), ('respvarname', 'O'), ('respfiletype', 'O'), ('nosync', 'O'), ('respfilefmt', 'O'), ('respfmtcode', 'O'), ('stimfile', 'O'), ('stimfiletype', 'O'), ('stimiconside', 'O'), ('stimfilecrf', 'O'), ('stimwindowsize', 'O'), ('stimfilefmt', 'O'), ('stimfmtcode', 'O'), ('addedby', 'O'), ('info', 'O'), ('lastmod', 'O'), ('stimpath', 'O'), ('stimspeedid', 'O'), ('spikes', 'O'), ('a_state', 'O'), ('singleid', 'O'), ('singlerawid', 'O'), ('area', 'O'), ('bad', 'O'), ('rawstimfile', 'O'), ('well', 'O')]),
#  PosixPath('V2Data1/DGrat/e0026/e0026.edrev3.005.p1_summary_file.mat'): array((8857, 'e0026', 795, 2929, 0, 1, '/auto/data/archive/ed_data/e2004-03-21/', 7842, 1, 'e0026.edrev3.005.p1.mat', 'psth', 0, 0, 'PSTH', 0, 'gratrev2004-192.index60.1.pixel.imsm', 1, '192,192', 3.0476, 192, 'pixel', 0, 'willmore', 'checkraw2cell.m', '2005-01-08 15:58:02', '/auto/data/archive/stimarchive/ED02/imsm/', 60, 1555, array([], dtype=float64), 780, 3824, 'V2', 0, 'index60.1', 2),
#        dtype=[('id', 'O'), ('cellid', 'O'), ('masterid', 'O'), ('rawid', 'O'), ('celldataid', 'O'), ('runclassid', 'O'), ('path', 'O'), ('resplen', 'O'), ('repcount', 'O'), ('respfile', 'O'), ('respvarname', 'O'), ('respfiletype', 'O'), ('nosync', 'O'), ('respfilefmt', 'O'), ('respfmtcode', 'O'), ('stimfile', 'O'), ('stimfiletype', 'O'), ('stimiconside', 'O'), ('stimfilecrf', 'O'), ('stimwindowsize', 'O'), ('stimfilefmt', 'O'), ('stimfmtcode', 'O'), ('addedby', 'O'), ('info', 'O'), ('lastmod', 'O'), ('stimpath', 'O'), ('stimspeedid', 'O'), ('spikes', 'O'), ('a_state', 'O'), ('singleid', 'O'), ('singlerawid', 'O'), ('area', 'O'), ('bad', 'O'), ('rawstimfile', 'O'), ('well', 'O')]),
#  PosixPath('V2Data1/DGrat/e0031/e0031.edrev3.006.p1_summary_file.mat'): array((8872, 'e0031', 802, 2959, 0, 1, '/auto/data/archive/ed_data/e2004-03-23/', 2228, 1, 'e0031.edrev3.006.p1.mat', 'psth', 0, 0, 'PSTH', 0, 'gratrev2004-128.index60.1.pixel.imsm', 1, '128,128', 4.2667, 128, 'pixel', 0, 'willmore', 'checkraw2cell.m', '2005-01-08 15:58:47', '/auto/data/archive/stimarchive/ED02/imsm/', 60, 19, array([], dtype=float64), 787, 3855, 'V2', 0, 'index60.1', 2),
#        dtype=[('id', 'O'), ('cellid', 'O'), ('masterid', 'O'), ('rawid', 'O'), ('celldataid', 'O'), ('runclassid', 'O'), ('path', 'O'), ('resplen', 'O'), ('repcount', 'O'), ('respfile', 'O'), ('respvarname', 'O'), ('respfiletype', 'O'), ('nosync', 'O'), ('respfilefmt', 'O'), ('respfmtcode', 'O'), ('stimfile', 'O'), ('stimfiletype', 'O'), ('stimiconside', 'O'), ('stimfilecrf', 'O'), ('stimwindowsize', 'O'), ('stimfilefmt', 'O'), ('stimfmtcode', 'O'), ('addedby', 'O'), ('info', 'O'), ('lastmod', 'O'), ('stimpath', 'O'), ('stimspeedid', 'O'), ('spikes', 'O'), ('a_state', 'O'), ('singleid', 'O'), ('singlerawid', 'O'), ('area', 'O'), ('bad', 'O'), ('rawstimfile', 'O'), ('well', 'O')]),
#  PosixPath('V2Data1/DGrat/e0031/e0031.edrev3.007.p1_summary_file.mat'): array((8873, 'e0031', 802, 2960, 0, 1, '/auto/data/archive/ed_data/e2004-03-23/', 1078, 1, 'e0031.edrev3.007.p1.mat', 'psth', 0, 0, 'PSTH', 0, 'gratrev2004-64.index60.1.pixel.imsm', 1, '64,64', 2.1333, 64, 'pixel', 0, 'willmore', 'checkraw2cell.m', '2005-01-08 15:58:48', '/auto/data/archive/stimarchive/ED02/imsm/', 60, 11, array([], dtype=float64), 787, 3856, 'V2', 0, 'index60.1', 2),
#        dtype=[('id', 'O'), ('cellid', 'O'), ('masterid', 'O'), ('rawid', 'O'), ('celldataid', 'O'), ('runclassid', 'O'), ('path', 'O'), ('resplen', 'O'), ('repcount', 'O'), ('respfile', 'O'), ('respvarname', 'O'), ('respfiletype', 'O'), ('nosync', 'O'), ('respfilefmt', 'O'), ('respfmtcode', 'O'), ('stimfile', 'O'), ('stimfiletype', 'O'), ('stimiconside', 'O'), ('stimfilecrf', 'O'), ('stimwindowsize', 'O'), ('stimfilefmt', 'O'), ('stimfmtcode', 'O'), ('addedby', 'O'), ('info', 'O'), ('lastmod', 'O'), ('stimpath', 'O'), ('stimspeedid', 'O'), ('spikes', 'O'), ('a_state', 'O'), ('singleid', 'O'), ('singlerawid', 'O'), ('area', 'O'), ('bad', 'O'), ('rawstimfile', 'O'), ('well', 'O')]),
#  PosixPath('V2Data1/DGrat/e0033/e0033.edrev3.006.p1_summary_file.mat'): array((8887, 'e0033', 806, 2986, 0, 1, '/auto/data/archive/ed_data/e2004-03-25/', 7751, 1, 'e0033.edrev3.006.p1.mat', 'psth', 0, 0, 'PSTH', 0, 'gratrev2004-192.index60.1.pixel.imsm', 1, '192,192', 3.2, 192, 'pixel', 0, 'willmore', 'checkraw2cell.m', '2005-01-08 15:59:57', '/auto/data/archive/stimarchive/ED02/imsm/', 60, 1378, array([], dtype=float64), 791, 3882, 'V2', 0, 'index60.1', 2),
#        dtype=[('id', 'O'), ('cellid', 'O'), ('masterid', 'O'), ('rawid', 'O'), ('celldataid', 'O'), ('runclassid', 'O'), ('path', 'O'), ('resplen', 'O'), ('repcount', 'O'), ('respfile', 'O'), ('respvarname', 'O'), ('respfiletype', 'O'), ('nosync', 'O'), ('respfilefmt', 'O'), ('respfmtcode', 'O'), ('stimfile', 'O'), ('stimfiletype', 'O'), ('stimiconside', 'O'), ('stimfilecrf', 'O'), ('stimwindowsize', 'O'), ('stimfilefmt', 'O'), ('stimfmtcode', 'O'), ('addedby', 'O'), ('info', 'O'), ('lastmod', 'O'), ('stimpath', 'O'), ('stimspeedid', 'O'), ('spikes', 'O'), ('a_state', 'O'), ('singleid', 'O'), ('singlerawid', 'O'), ('area', 'O'), ('bad', 'O'), ('rawstimfile', 'O'), ('well', 'O')]),
#  PosixPath('V2Data1/DGrat/e0033/e0033.edrev3.009.p1_summary_file.mat'): array((8890, 'e0033', 806, 2989, 0, 1, '/auto/data/archive/ed_data/e2004-03-25/', 7857, 1, 'e0033.edrev3.009.p1.mat', 'psth', 0, 0, 'PSTH', 0, 'gratrev2004
p1.mat', 'psth', 0, 0, 'PSTH', 0, 'natrev2005-128.index60.conf.pixel.imsm', 1, '128,128', 4.2667, 128, 'pixel', 0, 'willmore', 'checkraw2cell.m', '2005-01-08 19:24:38', '/auto/data/archive/stimarchive/ED02/imsm/', 60, 43, array([], dtype=float64), 1048, 4782, 'V2', 0, 'index60.conf', 5),
#        dtype=[('id', 'O'), ('cellid', 'O'), ('masterid', 'O'), ('rawid', 'O'), ('celldataid', 'O'), ('runclassid', 'O'), ('path', 'O'), ('resplen', 'O'), ('repcount', 'O'), ('respfile', 'O'), ('respvarname', 'O'), ('respfiletype', 'O'), ('nosync', 'O'), ('respfilefmt', 'O'), ('respfmtcode', 'O'), ('stimfile', 'O'), ('stimfiletype', 'O'), ('stimiconside', 'O'), ('stimfilecrf', 'O'), ('stimwindowsize', 'O'), ('stimfilefmt', 'O'), ('stimfmtcode', 'O'), ('addedby', 'O'), ('info', 'O'), ('lastmod', 'O'), ('stimpath', 'O'), ('stimspeedid', 'O'), ('spikes', 'O'), ('a_state', 'O'), ('singleid', 'O'), ('singlerawid', 'O'), ('area', 'O'), ('bad', 'O'), ('rawstimfile', 'O'), ('well', 'O')]),
#  PosixPath('V2Data20/NatRev/z0131/z0131.ezrev4.001.p1_summary_file.mat'): array((9288, 'z0131', 1076, 3887, 0, 2, '/auto/data/archive/zig_data/z2004-12-01/', 7964, 1, 'z0131.ezrev4.001.p1.mat', 'psth', 0, 0, 'PSTH', 0, 'natrev2005-160.index60.1.pixel.imsm', 1, '160,160', 3.2, 160, 'pixel', 0, 'willmore', 'checkraw2cell.m', '2005-01-08 19:24:40', '/auto/data/archive/stimarchive/ED02/imsm/', 60, 847, array([], dtype=float64), 1050, 4784, 'V2', 0, 'index60.1', 5),
#        dtype=[('id', 'O'), ('cellid', 'O'), ('masterid', 'O'), ('rawid', 'O'), ('celldataid', 'O'), ('runclassid', 'O'), ('path', 'O'), ('resplen', 'O'), ('repcount', 'O'), ('respfile', 'O'), ('respvarname', 'O'), ('respfiletype', 'O'), ('nosync', 'O'), ('respfilefmt', 'O'), ('respfmtcode', 'O'), ('stimfile', 'O'), ('stimfiletype', 'O'), ('stimiconside', 'O'), ('stimfilecrf', 'O'), ('stimwindowsize', 'O'), ('stimfilefmt', 'O'), ('stimfmtcode', 'O'), ('addedby', 'O'), ('info', 'O'), ('lastmod', 'O'), ('stimpath', 'O'), ('stimspeedid', 'O'), ('spikes', 'O'), ('a_state', 'O'), ('singleid', 'O'), ('singlerawid', 'O'), ('area', 'O'), ('bad', 'O'), ('rawstimfile', 'O'), ('well', 'O')]),
#  PosixPath('V2Data20/NatRev/z0131/z0131.ezrev4.002.p1_summary_file.mat'): array((9289, 'z0131', 1076, 3888, 0, 2, '/auto/data/archive/zig_data/z2004-12-01/', 600, 12, 'z0131.ezrev4.002.p1.mat', 'psth', 0, 0, 'PSTH', 0, 'natrev2005-160.index60.conf.pixel.imsm', 1, '160,160', 3.2, 160, 'pixel', 0, 'willmore', 'checkraw2cell.m', '2005-01-08 19:24:41', '/auto/data/archive/stimarchive/ED02/imsm/', 60, 64, array([], dtype=float64), 1050, 4785, 'V2', 0, 'index60.conf', 5),
#        dtype=[('id', 'O'), ('cellid', 'O'), ('masterid', 'O'), ('rawid', 'O'), ('celldataid', 'O'), ('runclassid', 'O'), ('path', 'O'), ('resplen', 'O'), ('repcount', 'O'), ('respfile', 'O'), ('respvarname', 'O'), ('respfiletype', 'O'), ('nosync', 'O'), ('respfilefmt', 'O'), ('respfmtcode', 'O'), ('stimfile', 'O'), ('stimfiletype', 'O'), ('stimiconside', 'O'), ('stimfilecrf', 'O'), ('stimwindowsize', 'O'), ('stimfilefmt', 'O'), ('stimfmtcode', 'O'), ('addedby', 'O'), ('info', 'O'), ('lastmod', 'O'), ('stimpath', 'O'), ('stimspeedid', 'O'), ('spikes', 'O'), ('a_state', 'O'), ('singleid', 'O'), ('singlerawid', 'O'), ('area', 'O'), ('bad', 'O'), ('rawstimfile', 'O'), ('well', 'O')])}

# %%
 len(celldatas)

# %%
summ_rel_path, celldata = list(celldatas.items())[223]
summ_rel_path, celldata

# %%
celldata.shape

# %%
celldata["cellid"]

# %%
type(celldata["cellid"])

# %%
celldata["cellid"].shape

# %%
celldata["cellid"].item()

# %%
{n: celldata[n].item() for n in celldata.dtype.names}

# %%
dict(summ_rel_path=summ_rel_path, **{n: celldata[n].item() for n in celldata.dtype.names})

# %%
celldatas_l = [dict(summ_rel_path=summ_rel_path, **{n: celldata[n].item() for n in celldata.dtype.names}) for summ_rel_path, celldata in celldatas.items()]
celldatas_l
# Out:
# [{'summ_rel_path': PosixPath('V2Data1/DGrat/e0022/e0022.edrev3.007.p1_summary_file.mat'),
#   'id': 8846,
#   'cellid': 'e0022',
#   'masterid': 788,
#   'rawid': 2901,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-03-18/',
#   'resplen': 7915,
#   'repcount': 1,
#   'respfile': 'e0022.edrev3.007.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-160.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '160,160',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 160,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 15:56:43',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 5852,
#   'a_state': array([], dtype=float64),
#   'singleid': 773,
#   'singlerawid': 3796,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 1},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0026/e0026.edrev3.005.p1_summary_file.mat'),
#   'id': 8857,
#   'cellid': 'e0026',
#   'masterid': 795,
#   'rawid': 2929,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-03-21/',
#   'resplen': 7842,
#   'repcount': 1,
#   'respfile': 'e0026.edrev3.005.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 3.0476,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 15:58:02',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1555,
#   'a_state': array([], dtype=float64),
#   'singleid': 780,
#   'singlerawid': 3824,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 2},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0031/e0031.edrev3.006.p1_summary_file.mat'),
#   'id': 8872,
#   'cellid': 'e0031',
#   'masterid': 802,
#   'rawid': 2959,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-03-23/',
#   'resplen': 2228,
#   'repcount': 1,
#   'respfile': 'e0031.edrev3.006.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-128.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 4.2667,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 15:58:47',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 19,
#   'a_state': array([], dtype=float64),
#   'singleid': 787,
#   'singlerawid': 3855,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 2},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0031/e0031.edrev3.007.p1_summary_file.mat'),
#   'id': 8873,
#   'cellid': 'e0031',
#   'masterid': 802,
#   'rawid': 2960,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-03-23/',
#   'resplen': 1078,
#   'repcount': 1,
#   'respfile': 'e0031.edrev3.007.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-64.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 2.1333,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 15:58:48',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 11,
#   'a_state': array([], dtype=float64),
#   'singleid': 787,
#   'singlerawid': 3856,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 2},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0033/e0033.edrev3.006.p1_summary_file.mat'),
#   'id': 8887,
#   'cellid': 'e0033',
#   'masterid': 806,
#   'rawid': 2986,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-03-25/',
#   'resplen': 7751,
#   'repcount': 1,
#   'respfile': 'e0033.edrev3.006.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 15:59:57',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1378,
#   'a_state': array([], dtype=float64),
#   'singleid': 791,
#   'singlerawid': 3882,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 2},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0033/e0033.edrev3.009.p1_summary_file.mat'),
#   'id': 8890,
#   'cellid': 'e0033',
#   'masterid': 806,
#   'rawid': 2989,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-03-25/',
#   'resplen': 7857,
#   'repcount': 1,
#   'respfile': 'e0033.edrev3.009.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-64.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 1.0667,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:00:17',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 3816,
#   'a_state': array([], dtype=float64),
#   'singleid': 791,
#   'singlerawid': 3885,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 2},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0034/e0034.edrev3.004.p1_summary_file.mat'),
#   'id': 8895,
#   'cellid': 'e0034',
#   'masterid': 807,
#   'rawid': 2995,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-03-25/',
#   'resplen': 7615,
#   'repcount': 1,
#   'respfile': 'e0034.edrev3.004.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-96.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '96,96',
#   'stimfilecrf': 4,
#   'stimwindowsize': 96,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:00:27',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 2117,
#   'a_state': array([], dtype=float64),
#   'singleid': 792,
#   'singlerawid': 3891,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 2},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0035/e0035.edrev3.007.p1_summary_file.mat'),
#   'id': 8901,
#   'cellid': 'e0035',
#   'masterid': 810,
#   'rawid': 3011,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-03-26/',
#   'resplen': 7809,
#   'repcount': 1,
#   'respfile': 'e0035.edrev3.007.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-32.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '32,32',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 32,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:00:39',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1129,
#   'a_state': array([], dtype=float64),
#   'singleid': 795,
#   'singlerawid': 3907,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 2},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0046/e0046.edrev3.006.p1_summary_file.mat'),
#   'id': 8933,
#   'cellid': 'e0046',
#   'masterid': 828,
#   'rawid': 3103,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-03-31/',
#   'resplen': 7975,
#   'repcount': 1,
#   'respfile': 'e0046.edrev3.006.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:02:17',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1448,
#   'a_state': array([], dtype=float64),
#   'singleid': 813,
#   'singlerawid': 4000,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 2},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0050/e0050.edrev3.005.p1_summary_file.mat'),
#   'id': 8951,
#   'cellid': 'e0050',
#   'masterid': 832,
#   'rawid': 3131,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-04-03/',
#   'resplen': 8000,
#   'repcount': 1,
#   'respfile': 'e0050.edrev3.005.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-256.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '256,256',
#   'stimfilecrf': 1.7067,
#   'stimwindowsize': 256,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:03:09',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 3177,
#   'a_state': array([], dtype=float64),
#   'singleid': 817,
#   'singlerawid': 4028,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 2},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0066/e0066.edrev3.004.p1_summary_file.mat'),
#   'id': 8989,
#   'cellid': 'e0066',
#   'masterid': 853,
#   'rawid': 3203,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-04-10/',
#   'resplen': 7575,
#   'repcount': 1,
#   'respfile': 'e0066.edrev3.004.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-256.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '256,256',
#   'stimfilecrf': 2.6667,
#   'stimwindowsize': 256,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:06:43',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 5099,
#   'a_state': array([], dtype=float64),
#   'singleid': 838,
#   'singlerawid': 4101,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 2},
#  {'summ_rel_path': PosixPath('V2Data1/DGrat/e0072/e0072.edrev3.005.p1_summary_file.mat'),
#   'id': 9003,
#   'cellid': 'e0072',
#   'masterid': 896,
#   'rawid': 3303,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-05-27/',
#   'resplen': 7832,
#   'repcount': 1,
#   'respfile': 'e0072.edrev3.005.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-64.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:08:06',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1991,
#   'a_state': array([], dtype=float64),
#   'singleid': 881,
#   'singlerawid': 4200,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 3},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0073/e0073.edrev3.005.p1_summary_file.mat'),
#   'id': 9008,
#   'cellid': 'e0073',
#   'masterid': 897,
#   'rawid': 3309,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-05-28/',
#   'resplen': 4435,
#   'repcount': 1,
#   'respfile': 'e0073.edrev3.005.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-64.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:10:25',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1137,
#   'a_state': array([], dtype=float64),
#   'singleid': 882,
#   'singlerawid': 4206,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 3},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0074/e0074.edrev3.009.p1_summary_file.mat'),
#   'id': 9019,
#   'cellid': 'e0074',
#   'masterid': 898,
#   'rawid': 3321,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-05-29/',
#   'resplen': 7719,
#   'repcount': 1,
#   'respfile': 'e0074.edrev3.009.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-96.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '96,96',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 96,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:14:46',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 2198,
#   'a_state': array([], dtype=float64),
#   'singleid': 883,
#   'singlerawid': 4218,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 3},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0075/e0075.edrev3.004.p1_summary_file.mat'),
#   'id': 9022,
#   'cellid': 'e0075',
#   'masterid': 899,
#   'rawid': 3326,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-05-30/',
#   'resplen': 7766,
#   'repcount': 1,
#   'respfile': 'e0075.edrev3.004.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-128.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 2.56,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:14:50',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 2622,
#   'a_state': array([], dtype=float64),
#   'singleid': 884,
#   'singlerawid': 4223,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 3},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0076/e0076.edrev3.003.p1_summary_file.mat'),
#   'id': 9027,
#   'cellid': 'e0076',
#   'masterid': 900,
#   'rawid': 3332,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-05-31/',
#   'resplen': 7817,
#   'repcount': 1,
#   'respfile': 'e0076.edrev3.003.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-160.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '160,160',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 160,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:18:03',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 5035,
#   'a_state': array([], dtype=float64),
#   'singleid': 885,
#   'singlerawid': 4229,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 3},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0076/e0076.edrev3.006.p1_summary_file.mat'),
#   'id': 9030,
#   'cellid': 'e0076',
#   'masterid': 900,
#   'rawid': 3335,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-05-31/',
#   'resplen': 600,
#   'repcount': 9,
#   'respfile': 'e0076.edrev3.006.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-160.index60.conf.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '160,160',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 160,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:18:06',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 399,
#   'a_state': array([], dtype=float64),
#   'singleid': 885,
#   'singlerawid': 4232,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 3},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0078/e0078.edrev3.006.p1_summary_file.mat'),
#   'id': 9037,
#   'cellid': 'e0078',
#   'masterid': 902,
#   'rawid': 3346,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-06-01/',
#   'resplen': 7480,
#   'repcount': 1,
#   'respfile': 'e0078.edrev3.006.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-128.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:19:05',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 4438,
#   'a_state': array([], dtype=float64),
#   'singleid': 887,
#   'singlerawid': 4243,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 3},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0080/e0080.edrev3.004.p1_summary_file.mat'),
#   'id': 9041,
#   'cellid': 'e0080',
#   'masterid': 904,
#   'rawid': 3352,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-06-02/',
#   'resplen': 7782,
#   'repcount': 1,
#   'respfile': 'e0080.edrev3.004.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:19:10',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1048,
#   'a_state': array([], dtype=float64),
#   'singleid': 889,
#   'singlerawid': 4249,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 3},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0080/e0080.edrev3.008.p1_summary_file.mat'),
#   'id': 9045,
#   'cellid': 'e0080',
#   'masterid': 904,
#   'rawid': 3356,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-06-02/',
#   'resplen': 600,
#   'repcount': 9,
#   'respfile': 'e0080.edrev3.008.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index60.conf.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:20:27',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 88,
#   'a_state': array([], dtype=float64),
#   'singleid': 889,
#   'singlerawid': 4253,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 3},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0107/e0107.edrev3.013.p1_summary_file.mat'),
#   'id': 9101,
#   'cellid': 'e0107',
#   'masterid': 950,
#   'rawid': 3508,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-06/',
#   'resplen': 7746,
#   'repcount': 1,
#   'respfile': 'e0107.edrev3.013.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 2.4,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:40:51',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 6068,
#   'a_state': array([], dtype=float64),
#   'singleid': 935,
#   'singlerawid': 4400,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0108/e0108.edrev3.012.p1_summary_file.mat'),
#   'id': 9110,
#   'cellid': 'e0108',
#   'masterid': 951,
#   'rawid': 3522,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-07/',
#   'resplen': 7881,
#   'repcount': 1,
#   'respfile': 'e0108.edrev3.012.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 2.4,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:42:54',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 4430,
#   'a_state': array([], dtype=float64),
#   'singleid': 936,
#   'singlerawid': 4414,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0109/e0109.edrev3.006.p1_summary_file.mat'),
#   'id': 9116,
#   'cellid': 'e0109',
#   'masterid': 952,
#   'rawid': 3531,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-08/',
#   'resplen': 7863,
#   'repcount': 1,
#   'respfile': 'e0109.edrev3.006.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:44:45',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 2577,
#   'a_state': array([], dtype=float64),
#   'singleid': 937,
#   'singlerawid': 4423,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data2/DGrat/e0110/e0110.edrev3.007.p1_summary_file.mat'),
#   'id': 9129,
#   'cellid': 'e0110',
#   'masterid': 953,
#   'rawid': 3547,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-09/',
#   'resplen': 7988,
#   'repcount': 1,
#   'respfile': 'e0110.edrev3.007.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 2.1333,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 16:55:38',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 7064,
#   'a_state': array([], dtype=float64),
#   'singleid': 938,
#   'singlerawid': 4439,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0115/e0115.edrev3.006.p1_summary_file.mat'),
#   'id': 9144,
#   'cellid': 'e0115',
#   'masterid': 957,
#   'rawid': 3572,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-11/',
#   'resplen': 7966,
#   'repcount': 1,
#   'respfile': 'e0115.edrev3.006.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-160.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '160,160',
#   'stimfilecrf': 4,
#   'stimwindowsize': 160,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:06:45',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 552,
#   'a_state': array([], dtype=float64),
#   'singleid': 942,
#   'singlerawid': 4464,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0121/e0121.edrev3.009.p1_summary_file.mat'),
#   'id': 9161,
#   'cellid': 'e0121',
#   'masterid': 961,
#   'rawid': 3598,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-13/',
#   'resplen': 7956,
#   'repcount': 1,
#   'respfile': 'e0121.edrev3.009.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 3.5556,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:14:36',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 2755,
#   'a_state': array([], dtype=float64),
#   'singleid': 946,
#   'singlerawid': 4490,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0121/e0121.edrev3.010.p1_summary_file.mat'),
#   'id': 9162,
#   'cellid': 'e0121',
#   'masterid': 961,
#   'rawid': 3599,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-13/',
#   'resplen': 4275,
#   'repcount': 1,
#   'respfile': 'e0121.edrev3.010.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-192.index15.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 3.5556,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:14:38',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 15,
#   'spikes': 2083,
#   'a_state': array([], dtype=float64),
#   'singleid': 946,
#   'singlerawid': 4491,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index15.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0121/e0121.edrev3.011.p1_summary_file.mat'),
#   'id': 9163,
#   'cellid': 'e0121',
#   'masterid': 961,
#   'rawid': 3600,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-13/',
#   'resplen': 4780,
#   'repcount': 1,
#   'respfile': 'e0121.edrev3.011.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-96.index15.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '96,96',
#   'stimfilecrf': 1.7778,
#   'stimwindowsize': 96,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:14:40',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 15,
#   'spikes': 3128,
#   'a_state': array([], dtype=float64),
#   'singleid': 946,
#   'singlerawid': 4492,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index15.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0121/e0121.edrev3.012.p1_summary_file.mat'),
#   'id': 9164,
#   'cellid': 'e0121',
#   'masterid': 961,
#   'rawid': 3601,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-13/',
#   'resplen': 11140,
#   'repcount': 1,
#   'respfile': 'e0121.edrev3.012.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-64.index15.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 1.1852,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:14:43',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 15,
#   'spikes': 9066,
#   'a_state': array([], dtype=float64),
#   'singleid': 946,
#   'singlerawid': 4493,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index15.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0123/e0123.edrev3.006.p1_summary_file.mat'),
#   'id': 9178,
#   'cellid': 'e0123',
#   'masterid': 963,
#   'rawid': 3622,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-15/',
#   'resplen': 7840,
#   'repcount': 1,
#   'respfile': 'e0123.edrev3.006.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-160.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '160,160',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 160,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:21:24',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 3810,
#   'a_state': array([], dtype=float64),
#   'singleid': 948,
#   'singlerawid': 4514,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0124/e0124.edrev3.007.p1_summary_file.mat'),
#   'id': 9191,
#   'cellid': 'e0124',
#   'masterid': 964,
#   'rawid': 3637,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-16/',
#   'resplen': 7920,
#   'repcount': 1,
#   'respfile': 'e0124.edrev3.007.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-128.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:31:22',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 9786,
#   'a_state': array([], dtype=float64),
#   'singleid': 949,
#   'singlerawid': 4529,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0125/e0125.edrev3.008.p1_summary_file.mat'),
#   'id': 9202,
#   'cellid': 'e0125',
#   'masterid': 966,
#   'rawid': 3651,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-17/',
#   'resplen': 7960,
#   'repcount': 1,
#   'respfile': 'e0125.edrev3.008.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-256.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '256,256',
#   'stimfilecrf': 3.3684,
#   'stimwindowsize': 256,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:40:05',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1235,
#   'a_state': array([], dtype=float64),
#   'singleid': 951,
#   'singlerawid': 4543,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0128/e0128.edrev3.004.p1_summary_file.mat'),
#   'id': 9207,
#   'cellid': 'e0128',
#   'masterid': 972,
#   'rawid': 3668,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-19/',
#   'resplen': 1112,
#   'repcount': 1,
#   'respfile': 'e0128.edrev3.004.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-128.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:41:22',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1,
#   'a_state': array([], dtype=float64),
#   'singleid': 957,
#   'singlerawid': 4560,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0128/e0128.edrev3.005.p1_summary_file.mat'),
#   'id': 9208,
#   'cellid': 'e0128',
#   'masterid': 972,
#   'rawid': 3669,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-19/',
#   'resplen': 1948,
#   'repcount': 1,
#   'respfile': 'e0128.edrev3.005.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-64.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 1.6,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:41:22',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 25,
#   'a_state': array([], dtype=float64),
#   'singleid': 957,
#   'singlerawid': 4561,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/e0128/e0128.edrev3.006.p1_summary_file.mat'),
#   'id': 9209,
#   'cellid': 'e0128',
#   'masterid': 972,
#   'rawid': 3670,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/ed_data/e2004-08-19/',
#   'resplen': 8723,
#   'repcount': 1,
#   'respfile': 'e0128.edrev3.006.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'gratrev2004-64.index15.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 1.6,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 17:41:25',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 15,
#   'spikes': 122,
#   'a_state': array([], dtype=float64),
#   'singleid': 957,
#   'singlerawid': 4562,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index15.1',
#   'well': 4},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/r0313/r0313.rev.003.p1_summary_file.mat'),
#   'id': 9471,
#   'cellid': 'r0313',
#   'masterid': 457,
#   'rawid': 1618,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-02/',
#   'resplen': 6278,
#   'repcount': 1,
#   'respfile': 'r0313.rev.003.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-hi-128.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:10:29',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 3014,
#   'a_state': array([], dtype=float64),
#   'singleid': 443,
#   'singlerawid': 2517,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/r0314/r0314.rev.001.p1_summary_file.mat'),
#   'id': 9473,
#   'cellid': 'r0314',
#   'masterid': 458,
#   'rawid': 1620,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-02/',
#   'resplen': 5692,
#   'repcount': 1,
#   'respfile': 'r0314.rev.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-hi-128.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.0476,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:10:37',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 3451,
#   'a_state': array([], dtype=float64),
#   'singleid': 444,
#   'singlerawid': 2520,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/r0315/r0315.rev.001.p1_summary_file.mat'),
#   'id': 9476,
#   'cellid': 'r0315',
#   'masterid': 459,
#   'rawid': 1624,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-02/',
#   'resplen': 5660,
#   'repcount': 1,
#   'respfile': 'r0315.rev.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-hi-128.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 2.9091,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:10:42',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 2689,
#   'a_state': array([], dtype=float64),
#   'singleid': 445,
#   'singlerawid': 2525,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/r0315/r0315.rev.003.p1_summary_file.mat'),
#   'id': 9478,
#   'cellid': 'r0315',
#   'masterid': 459,
#   'rawid': 1626,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-02/',
#   'resplen': 3108,
#   'repcount': 1,
#   'respfile': 'r0315.rev.003.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-apr-128.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 2.9091,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:10:47',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 817,
#   'a_state': array([], dtype=float64),
#   'singleid': 445,
#   'singlerawid': 2527,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/r0317/r0317.rev.001.p1_summary_file.mat'),
#   'id': 9481,
#   'cellid': 'r0317',
#   'masterid': 461,
#   'rawid': 1631,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-03/',
#   'resplen': 8919,
#   'repcount': 1,
#   'respfile': 'r0317.rev.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-hi-128.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.3684,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:10:53',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 101,
#   'a_state': array([], dtype=float64),
#   'singleid': 447,
#   'singlerawid': 2535,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data3/DGrat/r0317/r0317.rev.005.p1_summary_file.mat'),
#   'id': 9483,
#   'cellid': 'r0317',
#   'masterid': 461,
#   'rawid': 1636,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-03/',
#   'resplen': 8848,
#   'repcount': 1,
#   'respfile': 'r0317.rev.005.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-hi-64.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 1.6842,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:11:04',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 198,
#   'a_state': array([], dtype=float64),
#   'singleid': 447,
#   'singlerawid': 2538,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data4/DGrat/r0318/r0318.rev.001.p1_summary_file.mat'),
#   'id': 9484,
#   'cellid': 'r0318',
#   'masterid': 462,
#   'rawid': 1637,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-04/',
#   'resplen': 3998,
#   'repcount': 1,
#   'respfile': 'r0318.rev.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-hi-128.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.5556,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:11:05',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 330,
#   'a_state': array([], dtype=float64),
#   'singleid': 448,
#   'singlerawid': 2539,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data4/DGrat/r0327/r0327.rev.001.p1_summary_file.mat'),
#   'id': 9498,
#   'cellid': 'r0327',
#   'masterid': 470,
#   'rawid': 1660,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-06/',
#   'resplen': 8892,
#   'repcount': 1,
#   'respfile': 'r0327.rev.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-apr-192.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 2.7826,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:12:16',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 888,
#   'a_state': array([], dtype=float64),
#   'singleid': 456,
#   'singlerawid': 2564,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data4/DGrat/r0327/r0327.rev.002.p1_summary_file.mat'),
#   'id': 9499,
#   'cellid': 'r0327',
#   'masterid': 470,
#   'rawid': 1661,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-06/',
#   'resplen': 8964,
#   'repcount': 1,
#   'respfile': 'r0327.rev.002.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-apr-64.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 0.92754,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:12:18',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1626,
#   'a_state': array([], dtype=float64),
#   'singleid': 456,
#   'singlerawid': 2565,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data4/DGrat/r0328/r0328.rev.001.p1_summary_file.mat'),
#   'id': 9504,
#   'cellid': 'r0328',
#   'masterid': 471,
#   'rawid': 1667,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-07/',
#   'resplen': 8529,
#   'repcount': 1,
#   'respfile': 'r0328.rev.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-apr-128.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 4.4138,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:12:30',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 411,
#   'a_state': array([], dtype=float64),
#   'singleid': 457,
#   'singlerawid': 2571,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data4/DGrat/r0329/r0329.rev.001.p1_summary_file.mat'),
#   'id': 9507,
#   'cellid': 'r0329',
#   'masterid': 473,
#   'rawid': 1684,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-07/',
#   'resplen': 8634,
#   'repcount': 1,
#   'respfile': 'r0329.rev.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-apr-192.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 3.6923,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:12:38',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1530,
#   'a_state': array([], dtype=float64),
#   'singleid': 459,
#   'singlerawid': 2577,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data4/DGrat/r0330/r0330.rev.003.p1_summary_file.mat'),
#   'id': 9509,
#   'cellid': 'r0330',
#   'masterid': 474,
#   'rawid': 1691,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-08/',
#   'resplen': 8649,
#   'repcount': 1,
#   'respfile': 'r0330.rev.003.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-apr-192.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '192,192',
#   'stimfilecrf': 3.6923,
#   'stimwindowsize': 192,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:12:42',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 3005,
#   'a_state': array([], dtype=float64),
#   'singleid': 460,
#   'singlerawid': 2584,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data4/DGrat/r0332/r0332.rev.002.p1_summary_file.mat'),
#   'id': 9510,
#   'cellid': 'r0332',
#   'masterid': 476,
#   'rawid': 1704,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-09/',
#   'resplen': 8472,
#   'repcount': 1,
#   'respfile': 'r0332.rev.002.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-apr-128.index60.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 4,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:12:43',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 60,
#   'spikes': 1378,
#   'a_state': array([], dtype=float64),
#   'singleid': 462,
#   'singlerawid': 2597,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data4/DGrat/r0333/r0333.rev.001.p1_summary_file.mat'),
#   'id': 9512,
#   'cellid': 'r0333',
#   'masterid': 477,
#   'rawid': 1707,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-09/',
#   'resplen': 2264,
#   'repcount': 1,
#   'respfile': 'r0333.rev.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'onegrat-apr-128.index30.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 4.2667,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-10 12:12:48',
#   'stimpath': '/auto/data/archive/stimarchive/REESE17/imsm/',
#   'stimspeedid': 30,
#   'spikes': 404,
#   'a_state': array([], dtype=float64),
#   'singleid': 463,
#   'singlerawid': 2600,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index30',
#   'well': 17},
#  {'summ_rel_path': PosixPath('V2Data4/DGrat/r0336/r0336.rev.002.p1_summary_file.mat'),
#   'id': 9513,
#   'cellid': 'r0336',
#   'masterid': 478,
#   'rawid': 1710,
#   'celldataid': 0,
#   'runclassid': 1,
#   'path': '/auto/data/archive/reese_data/r2003-05-10/',
#   'resplen': 16651,
#   'repcount': 1,
#   'respfile': 'r0336.rev.002.p1.mat',
#   'respvarname': 'psth',
# ...
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 18:13:15',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 93,
#   'a_state': array([], dtype=float64),
#   'singleid': 1038,
#   'singlerawid': 4733,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data19/NatRev/z0120/z0120.ezrev4.001.p1_summary_file.mat'),
#   'id': 9259,
#   'cellid': 'z0120',
#   'masterid': 1065,
#   'rawid': 3840,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-23/',
#   'resplen': 7669,
#   'repcount': 1,
#   'respfile': 'z0120.ezrev4.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-96.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '96,96',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 96,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 18:17:11',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 4420,
#   'a_state': array([], dtype=float64),
#   'singleid': 1039,
#   'singlerawid': 4737,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data19/NatRev/z0120/z0120.ezrev4.002.p1_summary_file.mat'),
#   'id': 9260,
#   'cellid': 'z0120',
#   'masterid': 1065,
#   'rawid': 3841,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-23/',
#   'resplen': 600,
#   'repcount': 10,
#   'respfile': 'z0120.ezrev4.002.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-96.index60.conf.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '96,96',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 96,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 18:17:12',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 416,
#   'a_state': array([], dtype=float64),
#   'singleid': 1039,
#   'singlerawid': 4738,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data19/NatRev/z0124/z0124.ezrev4.000.p1_summary_file.mat'),
#   'id': 9265,
#   'cellid': 'z0124',
#   'masterid': 1069,
#   'rawid': 3854,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-25/',
#   'resplen': 7879,
#   'repcount': 1,
#   'respfile': 'z0124.ezrev4.000.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-256.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '256,256',
#   'stimfilecrf': 2.56,
#   'stimwindowsize': 256,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 18:22:47',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 11646,
#   'a_state': array([], dtype=float64),
#   'singleid': 1043,
#   'singlerawid': 4751,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data19/NatRev/z0124/z0124.ezrev4.001.p1_summary_file.mat'),
#   'id': 9266,
#   'cellid': 'z0124',
#   'masterid': 1069,
#   'rawid': 3855,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-25/',
#   'resplen': 600,
#   'repcount': 8,
#   'respfile': 'z0124.ezrev4.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-256.index60.conf.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '256,256',
#   'stimfilecrf': 2.56,
#   'stimwindowsize': 256,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 18:22:48',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 852,
#   'a_state': array([], dtype=float64),
#   'singleid': 1043,
#   'singlerawid': 4752,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data19/NatRev/z0125/z0125.ezrev4.001.p1_summary_file.mat'),
#   'id': 9270,
#   'cellid': 'z0125',
#   'masterid': 1070,
#   'rawid': 3861,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-27/',
#   'resplen': 7338,
#   'repcount': 1,
#   'respfile': 'z0125.ezrev4.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-64.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 18:46:05',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 316,
#   'a_state': array([], dtype=float64),
#   'singleid': 1044,
#   'singlerawid': 4758,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data19/NatRev/z0125/z0125.ezrev4.002.p1_summary_file.mat'),
#   'id': 9271,
#   'cellid': 'z0125',
#   'masterid': 1070,
#   'rawid': 3862,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-27/',
#   'resplen': 600,
#   'repcount': 11,
#   'respfile': 'z0125.ezrev4.002.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-64.index60.conf.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '64,64',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 64,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 18:46:06',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 23,
#   'a_state': array([], dtype=float64),
#   'singleid': 1044,
#   'singlerawid': 4759,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data19/NatRev/z0126/z0126.ezrev4.001.p1_summary_file.mat'),
#   'id': 9273,
#   'cellid': 'z0126',
#   'masterid': 1071,
#   'rawid': 3865,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-28/',
#   'resplen': 7909,
#   'repcount': 1,
#   'respfile': 'z0126.ezrev4.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-128.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 18:54:21',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 3044,
#   'a_state': array([], dtype=float64),
#   'singleid': 1045,
#   'singlerawid': 4762,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data19/NatRev/z0126/z0126.ezrev4.002.p1_summary_file.mat'),
#   'id': 9274,
#   'cellid': 'z0126',
#   'masterid': 1071,
#   'rawid': 3866,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-28/',
#   'resplen': 600,
#   'repcount': 11,
#   'respfile': 'z0126.ezrev4.002.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-128.index60.conf.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 18:54:22',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 258,
#   'a_state': array([], dtype=float64),
#   'singleid': 1045,
#   'singlerawid': 4763,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data20/NatRev/z0127/z0127.ezrev4.001.p1_summary_file.mat'),
#   'id': 9278,
#   'cellid': 'z0127',
#   'masterid': 1072,
#   'rawid': 3872,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-29/',
#   'resplen': 7961,
#   'repcount': 1,
#   'respfile': 'z0127.ezrev4.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-128.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.6571,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 19:10:06',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 6282,
#   'a_state': array([], dtype=float64),
#   'singleid': 1046,
#   'singlerawid': 4769,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data20/NatRev/z0127/z0127.ezrev4.002.p1_summary_file.mat'),
#   'id': 9279,
#   'cellid': 'z0127',
#   'masterid': 1072,
#   'rawid': 3873,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-29/',
#   'resplen': 600,
#   'repcount': 12,
#   'respfile': 'z0127.ezrev4.002.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-128.index60.conf.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.6571,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 19:10:07',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 450,
#   'a_state': array([], dtype=float64),
#   'singleid': 1046,
#   'singlerawid': 4770,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data20/NatRev/z0128/z0128.ezrev4.001.p1_summary_file.mat'),
#   'id': 9283,
#   'cellid': 'z0128',
#   'masterid': 1073,
#   'rawid': 3878,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-29/',
#   'resplen': 7953,
#   'repcount': 1,
#   'respfile': 'z0128.ezrev4.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-128.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 19:20:32',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 7279,
#   'a_state': array([], dtype=float64),
#   'singleid': 1047,
#   'singlerawid': 4775,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data20/NatRev/z0128/z0128.ezrev4.002.p1_summary_file.mat'),
#   'id': 9284,
#   'cellid': 'z0128',
#   'masterid': 1073,
#   'rawid': 3879,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-11-29/',
#   'resplen': 600,
#   'repcount': 12,
#   'respfile': 'z0128.ezrev4.002.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-128.index60.conf.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 19:20:33',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 573,
#   'a_state': array([], dtype=float64),
#   'singleid': 1047,
#   'singlerawid': 4776,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data20/NatRev/z0129/z0129.ezrev4.002.p1_summary_file.mat'),
#   'id': 9286,
#   'cellid': 'z0129',
#   'masterid': 1074,
#   'rawid': 3884,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-12-01/',
#   'resplen': 7987,
#   'repcount': 1,
#   'respfile': 'z0129.ezrev4.002.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-128.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 4.2667,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 19:24:37',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 653,
#   'a_state': array([], dtype=float64),
#   'singleid': 1048,
#   'singlerawid': 4781,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data20/NatRev/z0129/z0129.ezrev4.003.p1_summary_file.mat'),
#   'id': 9287,
#   'cellid': 'z0129',
#   'masterid': 1074,
#   'rawid': 3885,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-12-01/',
#   'resplen': 600,
#   'repcount': 10,
#   'respfile': 'z0129.ezrev4.003.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-128.index60.conf.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '128,128',
#   'stimfilecrf': 4.2667,
#   'stimwindowsize': 128,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 19:24:38',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 43,
#   'a_state': array([], dtype=float64),
#   'singleid': 1048,
#   'singlerawid': 4782,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data20/NatRev/z0131/z0131.ezrev4.001.p1_summary_file.mat'),
#   'id': 9288,
#   'cellid': 'z0131',
#   'masterid': 1076,
#   'rawid': 3887,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-12-01/',
#   'resplen': 7964,
#   'repcount': 1,
#   'respfile': 'z0131.ezrev4.001.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-160.index60.1.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '160,160',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 160,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 19:24:40',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 847,
#   'a_state': array([], dtype=float64),
#   'singleid': 1050,
#   'singlerawid': 4784,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.1',
#   'well': 5},
#  {'summ_rel_path': PosixPath('V2Data20/NatRev/z0131/z0131.ezrev4.002.p1_summary_file.mat'),
#   'id': 9289,
#   'cellid': 'z0131',
#   'masterid': 1076,
#   'rawid': 3888,
#   'celldataid': 0,
#   'runclassid': 2,
#   'path': '/auto/data/archive/zig_data/z2004-12-01/',
#   'resplen': 600,
#   'repcount': 12,
#   'respfile': 'z0131.ezrev4.002.p1.mat',
#   'respvarname': 'psth',
#   'respfiletype': 0,
#   'nosync': 0,
#   'respfilefmt': 'PSTH',
#   'respfmtcode': 0,
#   'stimfile': 'natrev2005-160.index60.conf.pixel.imsm',
#   'stimfiletype': 1,
#   'stimiconside': '160,160',
#   'stimfilecrf': 3.2,
#   'stimwindowsize': 160,
#   'stimfilefmt': 'pixel',
#   'stimfmtcode': 0,
#   'addedby': 'willmore',
#   'info': 'checkraw2cell.m',
#   'lastmod': '2005-01-08 19:24:41',
#   'stimpath': '/auto/data/archive/stimarchive/ED02/imsm/',
#   'stimspeedid': 60,
#   'spikes': 64,
#   'a_state': array([], dtype=float64),
#   'singleid': 1050,
#   'singlerawid': 4785,
#   'area': 'V2',
#   'bad': 0,
#   'rawstimfile': 'index60.conf',
#   'well': 5}]

# %%
celldatas_df = pd.DataFrame(celldatas_l)
celldatas_df
# Out:
#                                          summ_rel_path    id cellid  masterid  \
# 0    V2Data1/DGrat/e0022/e0022.edrev3.007.p1_summar...  8846  e0022       788
# 1    V2Data1/DGrat/e0026/e0026.edrev3.005.p1_summar...  8857  e0026       795
# 2    V2Data1/DGrat/e0031/e0031.edrev3.006.p1_summar...  8872  e0031       802
# 3    V2Data1/DGrat/e0031/e0031.edrev3.007.p1_summar...  8873  e0031       802
# 4    V2Data1/DGrat/e0033/e0033.edrev3.006.p1_summar...  8887  e0033       806
# ..                                                 ...   ...    ...       ...
# 412  V2Data20/NatRev/z0128/z0128.ezrev4.002.p1_summ...  9284  z0128      1073
# 413  V2Data20/NatRev/z0129/z0129.ezrev4.002.p1_summ...  9286  z0129      1074
# 414  V2Data20/NatRev/z0129/z0129.ezrev4.003.p1_summ...  9287  z0129      1074
# 415  V2Data20/NatRev/z0131/z0131.ezrev4.001.p1_summ...  9288  z0131      1076
# 416  V2Data20/NatRev/z0131/z0131.ezrev4.002.p1_summ...  9289  z0131      1076
#
#      rawid  celldataid  runclassid                                      path  \
# 0     2901           0           1   /auto/data/archive/ed_data/e2004-03-18/
# 1     2929           0           1   /auto/data/archive/ed_data/e2004-03-21/
# 2     2959           0           1   /auto/data/archive/ed_data/e2004-03-23/
# 3     2960           0           1   /auto/data/archive/ed_data/e2004-03-23/
# 4     2986           0           1   /auto/data/archive/ed_data/e2004-03-25/
# ..     ...         ...         ...                                       ...
# 412   3879           0           2  /auto/data/archive/zig_data/z2004-11-29/
# 413   3884           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 414   3885           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 415   3887           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 416   3888           0           2  /auto/data/archive/zig_data/z2004-12-01/
#
#      resplen  repcount  ...                                   stimpath  \
# 0       7915         1  ...  /auto/data/archive/stimarchive/ED02/imsm/
# 1       7842         1  ...  /auto/data/archive/stimarchive/ED02/imsm/
# 2       2228         1  ...  /auto/data/archive/stimarchive/ED02/imsm/
# 3       1078         1  ...  /auto/data/archive/stimarchive/ED02/imsm/
# 4       7751         1  ...  /auto/data/archive/stimarchive/ED02/imsm/
# ..       ...       ...  ...                                        ...
# 412      600        12  ...  /auto/data/archive/stimarchive/ED02/imsm/
# 413     7987         1  ...  /auto/data/archive/stimarchive/ED02/imsm/
# 414      600        10  ...  /auto/data/archive/stimarchive/ED02/imsm/
# 415     7964         1  ...  /auto/data/archive/stimarchive/ED02/imsm/
# 416      600        12  ...  /auto/data/archive/stimarchive/ED02/imsm/
#
#     stimspeedid  spikes  a_state singleid  singlerawid area  bad  \
# 0          60.0    5852       []      773         3796   V2    0
# 1          60.0    1555       []      780         3824   V2    0
# 2          60.0      19       []      787         3855   V2    0
# 3          60.0      11       []      787         3856   V2    0
# 4          60.0    1378       []      791         3882   V2    0
# ..          ...     ...      ...      ...          ...  ...  ...
# 412        60.0     573       []     1047         4776   V2    0
# 413        60.0     653       []     1048         4781   V2    0
# 414        60.0      43       []     1048         4782   V2    0
# 415        60.0     847       []     1050         4784   V2    0
# 416        60.0      64       []     1050         4785   V2    0
#
#       rawstimfile  well
# 0       index60.1     1
# 1       index60.1     2
# 2       index60.1     2
# 3       index60.1     2
# 4       index60.1     2
# ..            ...   ...
# 412  index60.conf     5
# 413     index60.1     5
# 414  index60.conf     5
# 415     index60.1     5
# 416  index60.conf     5
#
# [417 rows x 36 columns]

# %%
celldatas_df.apply(lambda r:  r["respfile"], axis=1)

# %%
celldatas_df.apply(lambda r:  v2_path.joinpath(r["summ_rel_path"].with_name(r["respfile"])), axis=1)[0]

# %%
celldatas_df["respfile_rel_path"] = celldatas_df.apply(lambda r:  r["summ_rel_path"].with_name(r["respfile"]), axis=1)
celldatas_df
# Out:
#                                          summ_rel_path    id cellid  masterid  \
# 0    V2Data1/DGrat/e0022/e0022.edrev3.007.p1_summar...  8846  e0022       788
# 1    V2Data1/DGrat/e0026/e0026.edrev3.005.p1_summar...  8857  e0026       795
# 2    V2Data1/DGrat/e0031/e0031.edrev3.006.p1_summar...  8872  e0031       802
# 3    V2Data1/DGrat/e0031/e0031.edrev3.007.p1_summar...  8873  e0031       802
# 4    V2Data1/DGrat/e0033/e0033.edrev3.006.p1_summar...  8887  e0033       806
# ..                                                 ...   ...    ...       ...
# 412  V2Data20/NatRev/z0128/z0128.ezrev4.002.p1_summ...  9284  z0128      1073
# 413  V2Data20/NatRev/z0129/z0129.ezrev4.002.p1_summ...  9286  z0129      1074
# 414  V2Data20/NatRev/z0129/z0129.ezrev4.003.p1_summ...  9287  z0129      1074
# 415  V2Data20/NatRev/z0131/z0131.ezrev4.001.p1_summ...  9288  z0131      1076
# 416  V2Data20/NatRev/z0131/z0131.ezrev4.002.p1_summ...  9289  z0131      1076
#
#      rawid  celldataid  runclassid                                      path  \
# 0     2901           0           1   /auto/data/archive/ed_data/e2004-03-18/
# 1     2929           0           1   /auto/data/archive/ed_data/e2004-03-21/
# 2     2959           0           1   /auto/data/archive/ed_data/e2004-03-23/
# 3     2960           0           1   /auto/data/archive/ed_data/e2004-03-23/
# 4     2986           0           1   /auto/data/archive/ed_data/e2004-03-25/
# ..     ...         ...         ...                                       ...
# 412   3879           0           2  /auto/data/archive/zig_data/z2004-11-29/
# 413   3884           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 414   3885           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 415   3887           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 416   3888           0           2  /auto/data/archive/zig_data/z2004-12-01/
#
#      resplen  repcount  ... stimspeedid spikes  a_state  singleid singlerawid  \
# 0       7915         1  ...        60.0   5852       []       773        3796
# 1       7842         1  ...        60.0   1555       []       780        3824
# 2       2228         1  ...        60.0     19       []       787        3855
# 3       1078         1  ...        60.0     11       []       787        3856
# 4       7751         1  ...        60.0   1378       []       791        3882
# ..       ...       ...  ...         ...    ...      ...       ...         ...
# 412      600        12  ...        60.0    573       []      1047        4776
# 413     7987         1  ...        60.0    653       []      1048        4781
# 414      600        10  ...        60.0     43       []      1048        4782
# 415     7964         1  ...        60.0    847       []      1050        4784
# 416      600        12  ...        60.0     64       []      1050        4785
#
#      area bad   rawstimfile well  \
# 0      V2   0     index60.1    1
# 1      V2   0     index60.1    2
# 2      V2   0     index60.1    2
# 3      V2   0     index60.1    2
# 4      V2   0     index60.1    2
# ..    ...  ..           ...  ...
# 412    V2   0  index60.conf    5
# 413    V2   0     index60.1    5
# 414    V2   0  index60.conf    5
# 415    V2   0     index60.1    5
# 416    V2   0  index60.conf    5
#
#                                  respfile_rel_path
# 0      V2Data1/DGrat/e0022/e0022.edrev3.007.p1.mat
# 1      V2Data1/DGrat/e0026/e0026.edrev3.005.p1.mat
# 2      V2Data1/DGrat/e0031/e0031.edrev3.006.p1.mat
# 3      V2Data1/DGrat/e0031/e0031.edrev3.007.p1.mat
# 4      V2Data1/DGrat/e0033/e0033.edrev3.006.p1.mat
# ..                                             ...
# 412  V2Data20/NatRev/z0128/z0128.ezrev4.002.p1.mat
# 413  V2Data20/NatRev/z0129/z0129.ezrev4.002.p1.mat
# 414  V2Data20/NatRev/z0129/z0129.ezrev4.003.p1.mat
# 415  V2Data20/NatRev/z0131/z0131.ezrev4.001.p1.mat
# 416  V2Data20/NatRev/z0131/z0131.ezrev4.002.p1.mat
#
# [417 rows x 37 columns]

# %%
celldatas_df["respfile_path"] = celldatas_df.apply(lambda r:  v2_path.joinpath(r["summ_rel_path"].with_name(r["respfile"])), axis=1)
celldatas_df
# Out:
#                                          summ_rel_path    id cellid  masterid  \
# 0    V2Data1/DGrat/e0022/e0022.edrev3.007.p1_summar...  8846  e0022       788
# 1    V2Data1/DGrat/e0026/e0026.edrev3.005.p1_summar...  8857  e0026       795
# 2    V2Data1/DGrat/e0031/e0031.edrev3.006.p1_summar...  8872  e0031       802
# 3    V2Data1/DGrat/e0031/e0031.edrev3.007.p1_summar...  8873  e0031       802
# 4    V2Data1/DGrat/e0033/e0033.edrev3.006.p1_summar...  8887  e0033       806
# ..                                                 ...   ...    ...       ...
# 412  V2Data20/NatRev/z0128/z0128.ezrev4.002.p1_summ...  9284  z0128      1073
# 413  V2Data20/NatRev/z0129/z0129.ezrev4.002.p1_summ...  9286  z0129      1074
# 414  V2Data20/NatRev/z0129/z0129.ezrev4.003.p1_summ...  9287  z0129      1074
# 415  V2Data20/NatRev/z0131/z0131.ezrev4.001.p1_summ...  9288  z0131      1076
# 416  V2Data20/NatRev/z0131/z0131.ezrev4.002.p1_summ...  9289  z0131      1076
#
#      rawid  celldataid  runclassid                                      path  \
# 0     2901           0           1   /auto/data/archive/ed_data/e2004-03-18/
# 1     2929           0           1   /auto/data/archive/ed_data/e2004-03-21/
# 2     2959           0           1   /auto/data/archive/ed_data/e2004-03-23/
# 3     2960           0           1   /auto/data/archive/ed_data/e2004-03-23/
# 4     2986           0           1   /auto/data/archive/ed_data/e2004-03-25/
# ..     ...         ...         ...                                       ...
# 412   3879           0           2  /auto/data/archive/zig_data/z2004-11-29/
# 413   3884           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 414   3885           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 415   3887           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 416   3888           0           2  /auto/data/archive/zig_data/z2004-12-01/
#
#      resplen  repcount  ... spikes a_state  singleid  singlerawid area  bad  \
# 0       7915         1  ...   5852      []       773         3796   V2    0
# 1       7842         1  ...   1555      []       780         3824   V2    0
# 2       2228         1  ...     19      []       787         3855   V2    0
# 3       1078         1  ...     11      []       787         3856   V2    0
# 4       7751         1  ...   1378      []       791         3882   V2    0
# ..       ...       ...  ...    ...     ...       ...          ...  ...  ...
# 412      600        12  ...    573      []      1047         4776   V2    0
# 413     7987         1  ...    653      []      1048         4781   V2    0
# 414      600        10  ...     43      []      1048         4782   V2    0
# 415     7964         1  ...    847      []      1050         4784   V2    0
# 416      600        12  ...     64      []      1050         4785   V2    0
#
#       rawstimfile  well                              respfile_rel_path  \
# 0       index60.1     1    V2Data1/DGrat/e0022/e0022.edrev3.007.p1.mat
# 1       index60.1     2    V2Data1/DGrat/e0026/e0026.edrev3.005.p1.mat
# 2       index60.1     2    V2Data1/DGrat/e0031/e0031.edrev3.006.p1.mat
# 3       index60.1     2    V2Data1/DGrat/e0031/e0031.edrev3.007.p1.mat
# 4       index60.1     2    V2Data1/DGrat/e0033/e0033.edrev3.006.p1.mat
# ..            ...   ...                                            ...
# 412  index60.conf     5  V2Data20/NatRev/z0128/z0128.ezrev4.002.p1.mat
# 413     index60.1     5  V2Data20/NatRev/z0129/z0129.ezrev4.002.p1.mat
# 414  index60.conf     5  V2Data20/NatRev/z0129/z0129.ezrev4.003.p1.mat
# 415     index60.1     5  V2Data20/NatRev/z0131/z0131.ezrev4.001.p1.mat
# 416  index60.conf     5  V2Data20/NatRev/z0131/z0131.ezrev4.002.p1.mat
#
#                                          respfile_path
# 0    /braintree/data2/active/users/jjpr/mkgu_packag...
# 1    /braintree/data2/active/users/jjpr/mkgu_packag...
# 2    /braintree/data2/active/users/jjpr/mkgu_packag...
# 3    /braintree/data2/active/users/jjpr/mkgu_packag...
# 4    /braintree/data2/active/users/jjpr/mkgu_packag...
# ..                                                 ...
# 412  /braintree/data2/active/users/jjpr/mkgu_packag...
# 413  /braintree/data2/active/users/jjpr/mkgu_packag...
# 414  /braintree/data2/active/users/jjpr/mkgu_packag...
# 415  /braintree/data2/active/users/jjpr/mkgu_packag...
# 416  /braintree/data2/active/users/jjpr/mkgu_packag...
#
# [417 rows x 38 columns]

# %%
celldatas_df.iloc[223]

# %%
celldatas_df["cellid"].is_unique

# %%
# %history
# Out:
# dir()
# dir()
# from pathlib import Path
# import pprint
# import os
# import json
# import numpy as np
# import pandas as pd
# import xarray as xr
# import jmespath
# from brainio_collection import list_stimulus_sets, list_assemblies, get_stimulus_set, get_assembly
# import plotly.express as px
# from plotly.subplots import make_subplots
# import plotly.graph_objects as go
# from brainio_base.assemblies import NeuronRecordingAssembly
# import scipy.io as sio
# import re
# source_netcdf_file = "/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/crcns_v2-1_neuronal.nc"
# example_csv_path = Path("/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data10/NatRev/data/e0052.edrev3.001.p1.mat.csv")
# example_mat_path = Path("/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data10/NatRev/e0052/e0052.edrev3.001.p1.mat")
# v2_path = example_csv_path.parents[3]
# v2_path
# summaries_glob = sorted(v2_path.glob("V2Data*/**/*summary_file.mat"))
# [f.relative_to(v2_path) for f in summaries_glob]
# len(summaries_glob)
# dir_key = lambda s: int(re.findall('(\d+)', s.relative_to(v2_path).parts[0])[-1])
# summaries_glob = sorted(summaries_glob, key=dir_key)
# summaries_glob
# celldatas = {}
# for s in summaries_glob:
#     rel_path = s.relative_to(v2_path)
#     mat = sio.loadmat(s, squeeze_me=True)
#     celldatas[rel_path] = mat["celldata"]
# celldatas
# celldatas_l = [dict(summ_rel_path=summ_rel_path, **{n: celldata[n].item() for n in celldata.dtype.names}) for summ_rel_path, celldata in celldatas.items()]
# celldatas_l
# celldatas_df = pd.DataFrame(celldatas_l)
# celldatas_df
# celldatas_df["respfile_rel_path"] = celldatas_df.apply(lambda r:  r["summ_rel_path"].with_name(r["respfile"]), axis=1)
# celldatas_df
# celldatas_df["respfile_path"] = celldatas_df.apply(lambda r:  v2_path.joinpath(r["summ_rel_path"].with_name(r["respfile"])), axis=1)
# celldatas_df
# %history

# %%
celldatas_df.groupby("cellid").count()

# %%
celldatas_df["respfile_rel_path"].is_unique

# %%
celldatas_df["respfile_path"].apply(lambda p: p.exists())

# %%
celldatas_df["respfile_path"].apply(lambda p: p.exists()).all()

# %%
celldatas_df.iloc[223]["respfile_path"]

# %%
example_resp_mat = sio.loadmat(celldatas_df.iloc[223]["respfile_path"], squeeze_me=True)
example_resp_mat

# %%
repr(example_resp_mat.keys())

# %%
example_resp_mat["h"]

# %%
def structured_to_dict(arr: np.ndarray): # per https://stackoverflow.com/a/67324508/1760084
    import numpy as np

    if np.ndim(arr) == 0:
        if arr.dtype.names == None:
            return arr.item()
        # accessing by int does *not* work when arr is a zero-dimensional array!
        return {k: structured_to_dict(arr[k]) for k in arr.dtype.names}
    return [structured_to_dict(v) for v in arr]

# %%
structured_to_dict(example_resp_mat["h"])

# %%
celldatas_df["respfile_path"].apply(lambda p: repr(sio.loadmat(p, squeeze_me=True).keys())).nunique()

# %%
for p in celldatas_df["respfile_path"]:
    mat = sio.loadmat(p, squeeze_me=True)
    print(Path(p.parts[-4:]), repr(sorted(mat.keys())))

# %%
sorted(example_resp_mat.keys())

# %%
celldatas_df[celldatas_df["respfile_rel_path"].astype("str")=="V2Data15/NatRev/m0260/m0260.mac_review.001.mat"]

# %%
celldatas_df.iloc[308]

# %%
for row in celldatas_df.itertuples():
    p = row.respfile_path
    try:
        mat = sio.loadmat(p, squeeze_me=True)
        print(row.respfile_rel_path, repr(sorted(mat.keys())))
    except Exception as e:
        print(row.respfile_rel_path, e)

# %%
def get_resp_mat_keys(respfile_path):
    try:
        mat = sio.loadmat(respfile_path, squeeze_me=True)
        return repr(sorted(mat.keys()))
#         print(row.respfile_rel_path, repr(sorted(mat.keys())))
    except Exception as e:
        return repr(e)
#         print(respfile_path, e)
get_resp_mat_keys(celldatas_df.iloc[223]["respfile_path"])
# Out:
# "['__globals__', '__header__', '__version__', 'chanid', 'droptime', 'eyepos', 'fext', 'flist', 'fpath', 'freps', 'h', 'kHzdata', 'matfile', 'outpath', 'phototime', 'plxfn', 'psth', 'r', 'refreshperframe', 'rnz', 's', 'shortstimlist', 'sid', 'smoothspikes', 'spiketime', 'stimtime', 'trialcount', 'unitid', 'xpos', 'ypos']"

# %%
celldatas_df["resp_mat_keys"] = celldatas_df.apply(lambda row: get_resp_mat_keys(row["respfile_path"]), axis=1)
celldatas_df["resp_mat_keys"]
# Out:
# 0      ['__globals__', '__header__', '__version__', '...
# 1      ['__globals__', '__header__', '__version__', '...
# 2      ['__globals__', '__header__', '__version__', '...
# 3      ['__globals__', '__header__', '__version__', '...
# 4      ['__globals__', '__header__', '__version__', '...
#                              ...
# 412    ['__globals__', '__header__', '__version__', '...
# 413    ['__globals__', '__header__', '__version__', '...
# 414    ['__globals__', '__header__', '__version__', '...
# 415    ['__globals__', '__header__', '__version__', '...
# 416    ['__globals__', '__header__', '__version__', '...
# Name: resp_mat_keys, Length: 417, dtype: object

# %%
celldatas_df["resp_mat_keys"].unique()

# %%
celldatas_df.iloc[223]["respfile_path"].name.split(".")[0]

# %%
celldatas_df["respload_esque_respvarname"] = celldatas_df["respfile_path"].apply(lambda p: p.name.split(".")[0])
celldatas_df["respload_esque_respvarname"]
# Out:
# 0      e0022
# 1      e0026
# 2      e0031
# 3      e0031
# 4      e0033
#        ...
# 412    z0128
# 413    z0129
# 414    z0129
# 415    z0131
# 416    z0131
# Name: respload_esque_respvarname, Length: 417, dtype: object

# %%
celldatas_df.apply(lambda row: "Unknown" in row["resp_mat_keys"], axis=1).value_counts()

# %%
celldatas_df.apply(lambda row: row["respload_esque_respvarname"] in row["resp_mat_keys"], axis=1).value_counts()

# %%
celldatas_df.apply(lambda row: row["respvarname"] in row["resp_mat_keys"], axis=1).value_counts()

# %%
celldatas_df["respvarname"].value_counts()

# %%
celldatas_df["respload_esque_respvarname"].value_counts()

# %%
celldatas_df[celldatas_df["respfile"].str.contains("andros")]["respfile"]

# %%
(celldatas_df["cellid"]==celldatas_df["respload_esque_respvarname"]).value_counts()

# %%
celldatas_df[["cellid", "respload_esque_respvarname"]].loc[celldatas_df["cellid"]!=celldatas_df["respload_esque_respvarname"]]

# %%
celldatas_df["respfile_rel_path"].apply(lambda p: p.parts[-2])

# %%
(celldatas_df["cellid"]==celldatas_df["respfile_rel_path"].apply(lambda p: p.parts[-2])).value_counts()

# %%
r = example_resp_mat["r"]
r

# %%
r.shape

# %%
nanmean_r = np.nanmean(r, axis=0)
nanmean_r

# %%
nanmean_r.shape

# %%
example_resp_mat.keys()

# %%
celldatas_df.iloc[223]["respfile_rel_path"]

# %%
fig01 = px.imshow(r, aspect="equal")
# fig01.update_layout(autosize=False)
fig01.update_layout(width=r.shape[1]*1000)
fig01.update_layout(coloraxis_showscale=False)
# fig01.update_layout(title=str(celldatas_df.iloc[223]["respfile_rel_path"]))
fig01

# %%
def add_resp_info(s):
    out_d = {}
    if "Unknown" not in s["resp_mat_keys"]:
        mat = sio.loadmat(s["respfile_path"], squeeze_me=True)
        r = mat["r"]
        out_d["r"] = r
        out_d["r_shape"] = r.shape
    else:
        out_d["r"] = np.empty(shape=(0, 0))
        out_d["r_shape"] = (0, 0)
    return pd.Series(out_d)

# %%
celldatas_df[["r", "r_shape"]] = celldatas_df.apply(add_resp_info, axis=1)
celldatas_df
# Out:
#                                          summ_rel_path    id cellid  masterid  \
# 0    V2Data1/DGrat/e0022/e0022.edrev3.007.p1_summar...  8846  e0022       788
# 1    V2Data1/DGrat/e0026/e0026.edrev3.005.p1_summar...  8857  e0026       795
# 2    V2Data1/DGrat/e0031/e0031.edrev3.006.p1_summar...  8872  e0031       802
# 3    V2Data1/DGrat/e0031/e0031.edrev3.007.p1_summar...  8873  e0031       802
# 4    V2Data1/DGrat/e0033/e0033.edrev3.006.p1_summar...  8887  e0033       806
# ..                                                 ...   ...    ...       ...
# 412  V2Data20/NatRev/z0128/z0128.ezrev4.002.p1_summ...  9284  z0128      1073
# 413  V2Data20/NatRev/z0129/z0129.ezrev4.002.p1_summ...  9286  z0129      1074
# 414  V2Data20/NatRev/z0129/z0129.ezrev4.003.p1_summ...  9287  z0129      1074
# 415  V2Data20/NatRev/z0131/z0131.ezrev4.001.p1_summ...  9288  z0131      1076
# 416  V2Data20/NatRev/z0131/z0131.ezrev4.002.p1_summ...  9289  z0131      1076
#
#      rawid  celldataid  runclassid                                      path  \
# 0     2901           0           1   /auto/data/archive/ed_data/e2004-03-18/
# 1     2929           0           1   /auto/data/archive/ed_data/e2004-03-21/
# 2     2959           0           1   /auto/data/archive/ed_data/e2004-03-23/
# 3     2960           0           1   /auto/data/archive/ed_data/e2004-03-23/
# 4     2986           0           1   /auto/data/archive/ed_data/e2004-03-25/
# ..     ...         ...         ...                                       ...
# 412   3879           0           2  /auto/data/archive/zig_data/z2004-11-29/
# 413   3884           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 414   3885           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 415   3887           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 416   3888           0           2  /auto/data/archive/zig_data/z2004-12-01/
#
#      resplen  repcount  ... area bad   rawstimfile  well  \
# 0       7915         1  ...   V2   0     index60.1     1
# 1       7842         1  ...   V2   0     index60.1     2
# 2       2228         1  ...   V2   0     index60.1     2
# 3       1078         1  ...   V2   0     index60.1     2
# 4       7751         1  ...   V2   0     index60.1     2
# ..       ...       ...  ...  ...  ..           ...   ...
# 412      600        12  ...   V2   0  index60.conf     5
# 413     7987         1  ...   V2   0     index60.1     5
# 414      600        10  ...   V2   0  index60.conf     5
# 415     7964         1  ...   V2   0     index60.1     5
# 416      600        12  ...   V2   0  index60.conf     5
#
#                                  respfile_rel_path  \
# 0      V2Data1/DGrat/e0022/e0022.edrev3.007.p1.mat
# 1      V2Data1/DGrat/e0026/e0026.edrev3.005.p1.mat
# 2      V2Data1/DGrat/e0031/e0031.edrev3.006.p1.mat
# 3      V2Data1/DGrat/e0031/e0031.edrev3.007.p1.mat
# 4      V2Data1/DGrat/e0033/e0033.edrev3.006.p1.mat
# ..                                             ...
# 412  V2Data20/NatRev/z0128/z0128.ezrev4.002.p1.mat
# 413  V2Data20/NatRev/z0129/z0129.ezrev4.002.p1.mat
# 414  V2Data20/NatRev/z0129/z0129.ezrev4.003.p1.mat
# 415  V2Data20/NatRev/z0131/z0131.ezrev4.001.p1.mat
# 416  V2Data20/NatRev/z0131/z0131.ezrev4.002.p1.mat
#
#                                          respfile_path  \
# 0    /braintree/data2/active/users/jjpr/mkgu_packag...
# 1    /braintree/data2/active/users/jjpr/mkgu_packag...
# 2    /braintree/data2/active/users/jjpr/mkgu_packag...
# 3    /braintree/data2/active/users/jjpr/mkgu_packag...
# 4    /braintree/data2/active/users/jjpr/mkgu_packag...
# ..                                                 ...
# 412  /braintree/data2/active/users/jjpr/mkgu_packag...
# 413  /braintree/data2/active/users/jjpr/mkgu_packag...
# 414  /braintree/data2/active/users/jjpr/mkgu_packag...
# 415  /braintree/data2/active/users/jjpr/mkgu_packag...
# 416  /braintree/data2/active/users/jjpr/mkgu_packag...
#
#                                          resp_mat_keys  \
# 0    ['__globals__', '__header__', '__version__', '...
# 1    ['__globals__', '__header__', '__version__', '...
# 2    ['__globals__', '__header__', '__version__', '...
# 3    ['__globals__', '__header__', '__version__', '...
# 4    ['__globals__', '__header__', '__version__', '...
# ..                                                 ...
# 412  ['__globals__', '__header__', '__version__', '...
# 413  ['__globals__', '__header__', '__version__', '...
# 414  ['__globals__', '__header__', '__version__', '...
# 415  ['__globals__', '__header__', '__version__', '...
# 416  ['__globals__', '__header__', '__version__', '...
#
#      respload_esque_respvarname  \
# 0                         e0022
# 1                         e0026
# 2                         e0031
# 3                         e0031
# 4                         e0033
# ..                          ...
# 412                       z0128
# 413                       z0129
# 414                       z0129
# 415                       z0131
# 416                       z0131
#
#                                                      r     r_shape
# 0    [[1.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 40)
# 1    [[1.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 36)
# 2    [[0.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 14)
# 3    [[0.0, nan, nan, nan, nan, nan, nan], [0.0, na...   (8000, 7)
# 4    [[0.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 40)
# ..                                                 ...         ...
# 412  [[1.0, nan, 0.0, 1.0, nan, 1.0, 1.0, nan, 1.0,...   (600, 39)
# 413  [[0.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 33)
# 414  [[0.0, nan, 1.0, 0.0, nan, 0.0, 0.0, nan, 0.0,...   (600, 34)
# 415  [[0.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 28)
# 416  [[0.0, nan, nan, 0.0, 0.0, nan, 0.0, 0.0, nan,...   (600, 41)
#
# [417 rows x 42 columns]

# %%
for row in celldatas_df[celldatas_df.index%20==0].itertuples():
    mat = sio.loadmat(row.respfile_path, squeeze_me=True)
    responses = mat["r"]
    fig = px.imshow(responses, title=str(row.respfile_rel_path), aspect="equal")
    fig.show()

# %%
celldatas_df["r_shape"].unique()

# %%
rows=4
cols=4
fig02 = make_subplots(rows=rows, cols=cols)
fig02.update_layout(height=rows*200+250)
for i in range(rows*cols):
#     print(i, i//cols, i%cols)
    fig02.add_trace(px.imshow(celldatas_df.iloc[i].r.reshape((1000, -1))).data[0], row=i//cols+1, col=i%cols+1)
fig02.show()

# %%
fig02 = px.imshow(responunique, title=str(row.respfile_rel_path), aspect="equal")
fig01 = px.imshow(r, aspect="equal")
# fig01.update_layout(autosize=False)
fig01.update_layout(width=r.shape[1]*1000)
fig01.update_layout(coloraxis_showscale=False)
# fig01.update_layout(title=str(celldatas_df.iloc[223]["respfile_rel_path"]))
fig01

# %%
np.count_nonzero(np.isnan(example_resp_mat["r"]))/example_resp_mat["r"].size

# %%
def get_nans_per(row):
    r = row["r"]
    if hasattr(r, "size") and r.size > 0:
        return np.count_nonzero(np.isnan(r))/r.size
    return np.nan

# %%
celldatas_df["nans_per"] = celldatas_df.apply(get_nans_per, axis=1)
celldatas_df
# Out:
#                                          summ_rel_path    id cellid  masterid  \
# 0    V2Data1/DGrat/e0022/e0022.edrev3.007.p1_summar...  8846  e0022       788
# 1    V2Data1/DGrat/e0026/e0026.edrev3.005.p1_summar...  8857  e0026       795
# 2    V2Data1/DGrat/e0031/e0031.edrev3.006.p1_summar...  8872  e0031       802
# 3    V2Data1/DGrat/e0031/e0031.edrev3.007.p1_summar...  8873  e0031       802
# 4    V2Data1/DGrat/e0033/e0033.edrev3.006.p1_summar...  8887  e0033       806
# ..                                                 ...   ...    ...       ...
# 412  V2Data20/NatRev/z0128/z0128.ezrev4.002.p1_summ...  9284  z0128      1073
# 413  V2Data20/NatRev/z0129/z0129.ezrev4.002.p1_summ...  9286  z0129      1074
# 414  V2Data20/NatRev/z0129/z0129.ezrev4.003.p1_summ...  9287  z0129      1074
# 415  V2Data20/NatRev/z0131/z0131.ezrev4.001.p1_summ...  9288  z0131      1076
# 416  V2Data20/NatRev/z0131/z0131.ezrev4.002.p1_summ...  9289  z0131      1076
#
#      rawid  celldataid  runclassid                                      path  \
# 0     2901           0           1   /auto/data/archive/ed_data/e2004-03-18/
# 1     2929           0           1   /auto/data/archive/ed_data/e2004-03-21/
# 2     2959           0           1   /auto/data/archive/ed_data/e2004-03-23/
# 3     2960           0           1   /auto/data/archive/ed_data/e2004-03-23/
# 4     2986           0           1   /auto/data/archive/ed_data/e2004-03-25/
# ..     ...         ...         ...                                       ...
# 412   3879           0           2  /auto/data/archive/zig_data/z2004-11-29/
# 413   3884           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 414   3885           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 415   3887           0           2  /auto/data/archive/zig_data/z2004-12-01/
# 416   3888           0           2  /auto/data/archive/zig_data/z2004-12-01/
#
#      resplen  repcount  ... bad   rawstimfile  well  \
# 0       7915         1  ...   0     index60.1     1
# 1       7842         1  ...   0     index60.1     2
# 2       2228         1  ...   0     index60.1     2
# 3       1078         1  ...   0     index60.1     2
# 4       7751         1  ...   0     index60.1     2
# ..       ...       ...  ...  ..           ...   ...
# 412      600        12  ...   0  index60.conf     5
# 413     7987         1  ...   0     index60.1     5
# 414      600        10  ...   0  index60.conf     5
# 415     7964         1  ...   0     index60.1     5
# 416      600        12  ...   0  index60.conf     5
#
#                                  respfile_rel_path  \
# 0      V2Data1/DGrat/e0022/e0022.edrev3.007.p1.mat
# 1      V2Data1/DGrat/e0026/e0026.edrev3.005.p1.mat
# 2      V2Data1/DGrat/e0031/e0031.edrev3.006.p1.mat
# 3      V2Data1/DGrat/e0031/e0031.edrev3.007.p1.mat
# 4      V2Data1/DGrat/e0033/e0033.edrev3.006.p1.mat
# ..                                             ...
# 412  V2Data20/NatRev/z0128/z0128.ezrev4.002.p1.mat
# 413  V2Data20/NatRev/z0129/z0129.ezrev4.002.p1.mat
# 414  V2Data20/NatRev/z0129/z0129.ezrev4.003.p1.mat
# 415  V2Data20/NatRev/z0131/z0131.ezrev4.001.p1.mat
# 416  V2Data20/NatRev/z0131/z0131.ezrev4.002.p1.mat
#
#                                          respfile_path  \
# 0    /braintree/data2/active/users/jjpr/mkgu_packag...
# 1    /braintree/data2/active/users/jjpr/mkgu_packag...
# 2    /braintree/data2/active/users/jjpr/mkgu_packag...
# 3    /braintree/data2/active/users/jjpr/mkgu_packag...
# 4    /braintree/data2/active/users/jjpr/mkgu_packag...
# ..                                                 ...
# 412  /braintree/data2/active/users/jjpr/mkgu_packag...
# 413  /braintree/data2/active/users/jjpr/mkgu_packag...
# 414  /braintree/data2/active/users/jjpr/mkgu_packag...
# 415  /braintree/data2/active/users/jjpr/mkgu_packag...
# 416  /braintree/data2/active/users/jjpr/mkgu_packag...
#
#                                          resp_mat_keys  \
# 0    ['__globals__', '__header__', '__version__', '...
# 1    ['__globals__', '__header__', '__version__', '...
# 2    ['__globals__', '__header__', '__version__', '...
# 3    ['__globals__', '__header__', '__version__', '...
# 4    ['__globals__', '__header__', '__version__', '...
# ..                                                 ...
# 412  ['__globals__', '__header__', '__version__', '...
# 413  ['__globals__', '__header__', '__version__', '...
# 414  ['__globals__', '__header__', '__version__', '...
# 415  ['__globals__', '__header__', '__version__', '...
# 416  ['__globals__', '__header__', '__version__', '...
#
#     respload_esque_respvarname  \
# 0                        e0022
# 1                        e0026
# 2                        e0031
# 3                        e0031
# 4                        e0033
# ..                         ...
# 412                      z0128
# 413                      z0129
# 414                      z0129
# 415                      z0131
# 416                      z0131
#
#                                                      r     r_shape  nans_per
# 0    [[1.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 40)  0.974500
# 1    [[1.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 36)  0.972628
# 2    [[0.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 14)  0.979705
# 3    [[0.0, nan, nan, nan, nan, nan, nan], [0.0, na...   (8000, 7)  0.980429
# 4    [[0.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 40)  0.974556
# ..                                                 ...         ...       ...
# 412  [[1.0, nan, 0.0, 1.0, nan, 1.0, 1.0, nan, 1.0,...   (600, 39)  0.540256
# 413  [[0.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 33)  0.964769
# 414  [[0.0, nan, 1.0, 0.0, nan, 0.0, 0.0, nan, 0.0,...   (600, 34)  0.530049
# 415  [[0.0, nan, nan, nan, nan, nan, nan, nan, nan,...  (8000, 28)  0.963817
# 416  [[0.0, nan, nan, 0.0, 0.0, nan, 0.0, 0.0, nan,...   (600, 41)  0.539878
#
# [417 rows x 43 columns]

# %%
celldatas_df.iloc[::10]

# %%
[np.unique(r[~np.isnan(r)]) for r in celldatas_df["r"]]

# %%
r = celldatas_df.iloc[223]["r"]
paper_height = r.shape[0]
paper_width = r.shape[1]
margin = 100
height = 2*margin + paper_height
width = 2*margin + paper_width
fig = px.imshow(r, aspect="equal")
fig.update_layout(height=height, width=width, margin=dict(l=margin, r=margin, t=margin, b=margin))
fig.show()
fig.show("json")

# %%
print(fig.layout.width)
# fig.show()

# %%
fig.data

# %%
fig.layout

# %%
len(celldatas_df)

# %%
list(celldatas_df.iloc[::10].index)

# %%
celldatas_df.iloc[::10].iloc[11]

# %%
step = 10
df = celldatas_df.iloc[::step]
cols = 4
rows = len(df)//cols + (1 if len(df)%cols else 0)
margin = 50
max_height = 500
height = 2*rows*margin + rows*max_height

fig = make_subplots(rows=rows, cols=cols, vertical_spacing=)
for i in range(len(df)):
    r = df.iloc[i].r
    fig.add_trace(px.imshow(r[:max_height, :]).data[0], row=i//cols+1, col=i%cols+1)
fig.update_layout(height=height)
fig.update_layout(coloraxis_showscale=False)
fig.update_yaxes(autorange="reversed")
fig.show()

# %%
print(8000*73)
print(8000*73//500)
print(500*225)
print((8000*73)//(500*225) + (1 if (8000*73)%(500*225) else 0))

# %%
def reshape(r, paper_height, paper_width):
    orig_aspect = r.shape[1]/r.shape[0]
    paper_aspect = paper_width/paper_height

# %%
step = 10
df = celldatas_df.iloc[::step]
cols = 4
rows = len(df)//cols + (1 if len(df)%cols else 0)
margin = 50
paper_height = 500
total_height = (2*margin) + ((rows-1)*margin) + (rows*paper_height)
paper_width = 225
total_width = (2*margin) + ((cols-1)*margin) + (cols*paper_width)

fig = make_subplots(rows=rows, cols=cols)
fig.update_layout(height=total_height, width=total_width, margin=dict(l=margin, r=margin, t=margin, b=margin))

for i in range(len(df)):
    r = df.iloc[i].r
    fig.add_trace(go.Heatmap(z=r[:max_height, :]), row=i//cols+1, col=i%cols+1)
fig.update_layout(height=height)
fig.update_layout(coloraxis_showscale=False)
fig.update_yaxes(autorange="reversed")
fig.show()

# %%
((500-2*100-3*50)/(3-1))/500

# %%
fig = make_subplots(3, 2, vertical_spacing=((500-2*100-3*50)/(3-1))/500) # should give 75 pixels of spacing
fig.update_layout(height=500)
fig.update_layout(margin=dict(t=100, b=100, l=100, r=100))
for i in range(2):
    for j in range(3):
        fig.add_trace(go.Scatter(x=[1, 2, 3], y=[4, 5, 6]), row=j+1, col=i+1)
fig.show()

# %%
cols = 2
rows = 3
margin = 50
paper_height = 100
total_height = (rows+1)*margin + rows*paper_height
vertical_spacing=margin/(total_height - 2*margin)
paper_width = 225
total_width = (cols+1)*margin + cols*paper_width
horizontal_spacing = margin/(total_width - 2*margin)

fig = make_subplots(rows, cols, vertical_spacing=vertical_spacing, horizontal_spacing=horizontal_spacing) 
fig.update_layout(height=total_height, width=total_width)
fig.update_layout(margin=dict(t=margin, b=margin, l=margin, r=margin))
fig.update_yaxes(autorange="reversed")
for i in range(cols):
    for j in range(rows):
        fig.add_trace(go.Heatmap(z=np.identity(10), showscale=False), row=j+1, col=i+1)
fig.show()
print(f"cols: {cols}  rows: {rows}")
print(f"margin: {margin}  paper height: {paper_height}  paper width: {paper_width}")
print(f"total height: {total_height}  total width: {total_width}")

# %%
np.identity(10)

# %%
# raise Exception

step = 10
df = celldatas_df.iloc[::step]
cols = 4
rows = len(df)//cols + (1 if len(df)%cols else 0)
margin = 50
paper_height = 500
total_height = (rows+1)*margin + rows*paper_height
vertical_spacing=margin/(total_height - 2*margin)
paper_width = 225
total_width = (cols+1)*margin + cols*paper_width
horizontal_spacing = margin/(total_width - 2*margin)

fig = make_subplots(rows, cols, vertical_spacing=vertical_spacing, horizontal_spacing=horizontal_spacing) 
fig.update_layout(height=total_height, width=total_width)
fig.update_layout(margin=dict(t=margin, b=margin, l=margin, r=margin))
fig.update_yaxes(autorange="reversed")
        
# for i in range(len(df)):
for i in range(1):
    r = df.iloc[i].r
    fig.add_trace(go.Heatmap(z=r, showscale=False), row=i//cols+1, col=i%cols+1)

# fig.show()
fig.show(renderer="png", height=total_height, width=total_width)
print(f"cols: {cols}  rows: {rows}")
print(f"margin: {margin}  paper height: {paper_height}  paper width: {paper_width}")
print(f"total height: {total_height}  total width: {total_width}")
# Out:
# cols: 4  rows: 11
# margin: 50  paper height: 500  paper width: 225
# total height: 6100  total width: 1150

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
# %history
# Out:
# dir()
# dir()
# from pathlib import Path
# import pprint
# import os
# import json
# import numpy as np
# import pandas as pd
# import xarray as xr
# import jmespath
# from brainio_collection import list_stimulus_sets, list_assemblies, get_stimulus_set, get_assembly
# import plotly.express as px
# from plotly.subplots import make_subplots
# import plotly.graph_objects as go
# from brainio_base.assemblies import NeuronRecordingAssembly
# import scipy.io as sio
# import re
# source_netcdf_file = "/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/crcns_v2-1_neuronal.nc"
# example_csv_path = Path("/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data10/NatRev/data/e0052.edrev3.001.p1.mat.csv")
# example_mat_path = Path("/braintree/data2/active/users/jjpr/mkgu_packaging/crcns/v2-1/V2Data10/NatRev/e0052/e0052.edrev3.001.p1.mat")
# v2_path = example_csv_path.parents[3]
# v2_path
# summaries_glob = sorted(v2_path.glob("V2Data*/**/*summary_file.mat"))
# [f.relative_to(v2_path) for f in summaries_glob]
# len(summaries_glob)
# dir_key = lambda s: int(re.findall('(\d+)', s.relative_to(v2_path).parts[0])[-1])
# summaries_glob = sorted(summaries_glob, key=dir_key)
# summaries_glob
# celldatas = {}
# for s in summaries_glob:
#     rel_path = s.relative_to(v2_path)
#     mat = sio.loadmat(s, squeeze_me=True)
#     celldatas[rel_path] = mat["celldata"]
# celldatas
# celldatas_l = [dict(summ_rel_path=summ_rel_path, **{n: celldata[n].item() for n in celldata.dtype.names}) for summ_rel_path, celldata in celldatas.items()]
# celldatas_l
# celldatas_df = pd.DataFrame(celldatas_l)
# celldatas_df
# celldatas_df["respfile_rel_path"] = celldatas_df.apply(lambda r:  r["summ_rel_path"].with_name(r["respfile"]), axis=1)
# celldatas_df
# celldatas_df["respfile_path"] = celldatas_df.apply(lambda r:  v2_path.joinpath(r["summ_rel_path"].with_name(r["respfile"])), axis=1)
# celldatas_df
# %history
# def structured_to_dict(arr: np.ndarray): # per https://stackoverflow.com/a/67324508/1760084
#     import numpy as np
#
#     if np.ndim(arr) == 0:
#         if arr.dtype.names == None:
#             return arr.item()
#         # accessing by int does *not* work when arr is a zero-dimensional array!
#         return {k: structured_to_dict(arr[k]) for k in arr.dtype.names}
#     return [structured_to_dict(v) for v in arr]
# def get_resp_mat_keys(respfile_path):
#     try:
#         mat = sio.loadmat(respfile_path, squeeze_me=True)
#         return repr(sorted(mat.keys()))
# #         print(row.respfile_rel_path, repr(sorted(mat.keys())))
#     except Exception as e:
#         return repr(e)
# #         print(respfile_path, e)
# get_resp_mat_keys(celldatas_df.iloc[223]["respfile_path"])
# celldatas_df["resp_mat_keys"] = celldatas_df.apply(lambda row: get_resp_mat_keys(row["respfile_path"]), axis=1)
# celldatas_df["resp_mat_keys"]
# celldatas_df["respload_esque_respvarname"] = celldatas_df["respfile_path"].apply(lambda p: p.name.split(".")[0])
# celldatas_df["respload_esque_respvarname"]
# def add_resp_info(s):
#     out_d = {}
#     if "Unknown" not in s["resp_mat_keys"]:
#         mat = sio.loadmat(s["respfile_path"], squeeze_me=True)
#         r = mat["r"]
#         out_d["r"] = r
#         out_d["r_shape"] = r.shape
#     else:
#         out_d["r"] = np.empty(shape=(0, 0))
#         out_d["r_shape"] = (0, 0)
#     return pd.Series(out_d)
# celldatas_df[["r", "r_shape"]] = celldatas_df.apply(add_resp_info, axis=1)
# celldatas_df
# def get_nans_per(row):
#     r = row["r"]
#     if hasattr(r, "size") and r.size > 0:
#         return np.count_nonzero(np.isnan(r))/r.size
#     return np.nan
# celldatas_df["nans_per"] = celldatas_df.apply(get_nans_per, axis=1)
# celldatas_df
# step = 10
# df = celldatas_df.iloc[::step]
# cols = 4
# rows = len(df)//cols + (1 if len(df)%cols else 0)
# margin = 50
# paper_height = 500
# total_height = (rows+1)*margin + rows*paper_height
# vertical_spacing=margin/(total_height - 2*margin)
# paper_width = 225
# total_width = (cols+1)*margin + cols*paper_width
# horizontal_spacing = margin/(total_width - 2*margin)
#
# fig = make_subplots(rows, cols, vertical_spacing=vertical_spacing, horizontal_spacing=horizontal_spacing)
# fig.update_layout(height=total_height, width=total_width)
# fig.update_layout(margin=dict(t=margin, b=margin, l=margin, r=margin))
# fig.update_yaxes(autorange="reversed")
#
# for i in range(len(df)):
#     r = df.iloc[i].r
#     fig.add_trace(go.Heatmap(z=r, showscale=False), row=i//cols+1, col=i%cols+1)
#
# fig.show()
# print(f"cols: {cols}  rows: {rows}")
# print(f"margin: {margin}  paper height: {paper_height}  paper width: {paper_width}")
# print(f"total height: {total_height}  total width: {total_width}")
# raise Exception
#
# step = 10
# df = celldatas_df.iloc[::step]
# cols = 4
# rows = len(df)//cols + (1 if len(df)%cols else 0)
# margin = 50
# paper_height = 500
# total_height = (rows+1)*margin + rows*paper_height
# vertical_spacing=margin/(total_height - 2*margin)
# paper_width = 225
# total_width = (cols+1)*margin + cols*paper_width
# horizontal_spacing = margin/(total_width - 2*margin)
#
# fig = make_subplots(rows, cols, vertical_spacing=vertical_spacing, horizontal_spacing=horizontal_spacing)
# fig.update_layout(height=total_height, width=total_width)
# fig.update_layout(margin=dict(t=margin, b=margin, l=margin, r=margin))
# fig.update_yaxes(autorange="reversed")
#
# for i in range(len(df)):
#     r = df.iloc[i].r
#     fig.add_trace(go.Heatmap(z=r, showscale=False), row=i//cols+1, col=i%cols+1)
#
# fig.show()
# print(f"cols: {cols}  rows: {rows}")
# print(f"margin: {margin}  paper height: {paper_height}  paper width: {paper_width}")
# print(f"total height: {total_height}  total width: {total_width}")
# raise Exception
#
# step = 10
# df = celldatas_df.iloc[::step]
# cols = 4
# rows = len(df)//cols + (1 if len(df)%cols else 0)
# margin = 50
# paper_height = 500
# total_height = (rows+1)*margin + rows*paper_height
# vertical_spacing=margin/(total_height - 2*margin)
# paper_width = 225
# total_width = (cols+1)*margin + cols*paper_width
# horizontal_spacing = margin/(total_width - 2*margin)
#
# fig = make_subplots(rows, cols, vertical_spacing=vertical_spacing, horizontal_spacing=horizontal_spacing)
# fig.update_layout(height=total_height, width=total_width)
# fig.update_layout(margin=dict(t=margin, b=margin, l=margin, r=margin))
# fig.update_yaxes(autorange="reversed")
#
# # for i in range(len(df)):
# for i in range(1):
#     r = df.iloc[i].r
#     fig.add_trace(go.Heatmap(z=r, showscale=False), row=i//cols+1, col=i%cols+1)
#
# fig.show()
# print(f"cols: {cols}  rows: {rows}")
# print(f"margin: {margin}  paper height: {paper_height}  paper width: {paper_width}")
# print(f"total height: {total_height}  total width: {total_width}")
# # raise Exception
#
# step = 10
# df = celldatas_df.iloc[::step]
# cols = 4
# rows = len(df)//cols + (1 if len(df)%cols else 0)
# margin = 50
# paper_height = 500
# total_height = (rows+1)*margin + rows*paper_height
# vertical_spacing=margin/(total_height - 2*margin)
# paper_width = 225
# total_width = (cols+1)*margin + cols*paper_width
# horizontal_spacing = margin/(total_width - 2*margin)
#
# fig = make_subplots(rows, cols, vertical_spacing=vertical_spacing, horizontal_spacing=horizontal_spacing)
# fig.update_layout(height=total_height, width=total_width)
# fig.update_layout(margin=dict(t=margin, b=margin, l=margin, r=margin))
# fig.update_yaxes(autorange="reversed")
#
# # for i in range(len(df)):
# for i in range(1):
#     r = df.iloc[i].r
#     fig.add_trace(go.Heatmap(z=r, showscale=False), row=i//cols+1, col=i%cols+1)
#
# fig.show()
# print(f"cols: {cols}  rows: {rows}")
# print(f"margin: {margin}  paper height: {paper_height}  paper width: {paper_width}")
# print(f"total height: {total_height}  total width: {total_width}")
# # raise Exception
#
# step = 10
# df = celldatas_df.iloc[::step]
# cols = 4
# rows = len(df)//cols + (1 if len(df)%cols else 0)
# margin = 50
# paper_height = 500
# total_height = (rows+1)*margin + rows*paper_height
# vertical_spacing=margin/(total_height - 2*margin)
# paper_width = 225
# total_width = (cols+1)*margin + cols*paper_width
# horizontal_spacing = margin/(total_width - 2*margin)
#
# fig = make_subplots(rows, cols, vertical_spacing=vertical_spacing, horizontal_spacing=horizontal_spacing)
# fig.update_layout(height=total_height, width=total_width)
# fig.update_layout(margin=dict(t=margin, b=margin, l=margin, r=margin))
# fig.update_yaxes(autorange="reversed")
#
# # for i in range(len(df)):
# for i in range(1):
#     r = df.iloc[i].r
#     fig.add_trace(go.Heatmap(z=r, showscale=False), row=i//cols+1, col=i%cols+1)
#
# # fig.show()
# fig.show(renderer="png")
# print(f"cols: {cols}  rows: {rows}")
# print(f"margin: {margin}  paper height: {paper_height}  paper width: {paper_width}")
# print(f"total height: {total_height}  total width: {total_width}")
# %history

# %%
step = 10
df = celldatas_df.iloc[::step]
cols = 4
rows = len(df)//cols + (1 if len(df)%cols else 0)
margin = 50
paper_height = 500
total_height = (rows+1)*margin + rows*paper_height
vertical_spacing=margin/(total_height - 2*margin)
paper_width = 225
total_width = (cols+1)*margin + cols*paper_width
horizontal_spacing = margin/(total_width - 2*margin)

fig = make_subplots(rows, cols, vertical_spacing=vertical_spacing, horizontal_spacing=horizontal_spacing) 
fig.update_layout(height=total_height, width=total_width)
fig.update_layout(margin=dict(t=margin, b=margin, l=margin, r=margin))
fig.update_yaxes(autorange="reversed")
        
for i in range(len(df)):
    r = df.iloc[i].r
    fig.add_trace(go.Heatmap(z=r, showscale=False), row=i//cols+1, col=i%cols+1)

fig.show(renderer="png", height=total_height, width=total_width)
print(f"cols: {cols}  rows: {rows}")
print(f"margin: {margin}  paper height: {paper_height}  paper width: {paper_width}")
print(f"total height: {total_height}  total width: {total_width}")
# Out:
# cols: 4  rows: 11
# margin: 50  paper height: 500  paper width: 225
# total height: 6100  total width: 1150
